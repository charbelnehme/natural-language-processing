# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from datetime import datetime, timedelta
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi
from alpaca_trade_api.rest import REST, TimeFrame, TimeFrameUnit
import nltk as nltk
from newsapi.newsapi_client import NewsApiClient
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
import matplotlib.pyplot as plt
import dataframe_image as dfi

# %matplotlib inline

print('NLP Homework Assignment')
print('Student Name: Charbel Nehme')
# Out:
# NLP Homework Assignment
# Student Name: Charbel Nehme

# %%
# Load .env enviroment variables
load_dotenv()

# Set News API Key
newsapi = NewsApiClient(api_key=os.environ["NEWS_API_KEY"])

# Set Alpaca API key and secret
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")

api = tradeapi.REST(alpaca_api_key, alpaca_secret_key, api_version='v2')

# %%
# Create a newsapi client
api_key = os.getenv("NEWS_API_KEY")
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_news_en = newsapi.get_everything(
    q="bitcoin",
    language="en"
)

# Show the total number of news
bitcoin_news_en["totalResults"]
print('There are {"totalResults"} Bitcoin news articles in the English media.')
# Out:
# There are {"totalResults"} Bitcoin news articles in the English media.

# %%
# Fetch the Ethereum news articles
ethereum_news_en = newsapi.get_everything(
    q="bitcoin",
    language="en"
)

# Show the total number of news
ethereum_news_en["totalResults"]
print('There are {"totalResults"} Ethereum news articles in the English media')
# Out:
# There are {"totalResults"} Ethereum news articles in the English media

# %%
# Function to create a dataframe for Bitcoin news in English
def create_df(news, language):
    articles = []
    for article in news:
        try:
            title = article["title"]
            description = article["description"]
            text = article["content"]
            date = article["publishedAt"][:10]

            articles.append({
                "title": title,
                "description": description,
                "text": text,
                "date": date,
                "language": language
            })
        except AttributeError as ae:
            pass

    return pd.DataFrame(articles)

# %%
# Create a DataFrame with Bitcoin news
bitcoin_df = create_df(bitcoin_news_en["articles"], "en")
bitcoin_df.head()
# Out:
#                                                title  \
# 0  Ex-Party Producer Charged in $2.7 Million Bitc...
# 1  Everyone Has Crypto FOMO, but Does It Belong i...
# 2  If you’re a Russian YouTuber, how do you get p...
# 3  El Salvador turns to Binance for help on bitco...
# 4                         Why Isn't Bitcoin Booming?
#
#                                          description  \
# 0  Thomas Spieker’s clients included dark-web dru...
# 1  A growing array of investment options make it ...
# 2  Russian creators are shut off from the global ...
# 3  El Salvador is seeking support from cryptocurr...
# 4  "Bitcoin was seen by many of its libertarian-l...
#
#                                                 text        date language
# 0  Mr. Spiekers most prominent customer, whom he ...  2022-03-24       en
# 1  Other fund vehicles hold crypto directly, but ...  2022-03-24       en
# 2  When Russia invaded Ukraine, Niki Proshin was ...  2022-03-17       en
# 3  SAN SALVADOR, March 23 (Reuters) - El Salvador...  2022-03-23       en
# 4  "Bitcoin was seen by many of its libertarian-l...  2022-03-12       en

# %%
# Save bitcoin dataframe to CSV
file_path = (".\dataframe_csv/bitcoin_news.csv")
bitcoin_df.to_csv(file_path, index=False, encoding='utf-8-sig')

# %%
# Create a DataFrame with Ethereum news
ethereum_df = create_df(ethereum_news_en["articles"], "en")
ethereum_df.head()
# Out:
#                                                title  \
# 0  Ex-Party Producer Charged in $2.7 Million Bitc...
# 1  Everyone Has Crypto FOMO, but Does It Belong i...
# 2  If you’re a Russian YouTuber, how do you get p...
# 3  El Salvador turns to Binance for help on bitco...
# 4                         Why Isn't Bitcoin Booming?
#
#                                          description  \
# 0  Thomas Spieker’s clients included dark-web dru...
# 1  A growing array of investment options make it ...
# 2  Russian creators are shut off from the global ...
# 3  El Salvador is seeking support from cryptocurr...
# 4  "Bitcoin was seen by many of its libertarian-l...
#
#                                                 text        date language
# 0  Mr. Spiekers most prominent customer, whom he ...  2022-03-24       en
# 1  Other fund vehicles hold crypto directly, but ...  2022-03-24       en
# 2  When Russia invaded Ukraine, Niki Proshin was ...  2022-03-17       en
# 3  SAN SALVADOR, March 23 (Reuters) - El Salvador...  2022-03-23       en
# 4  "Bitcoin was seen by many of its libertarian-l...  2022-03-12       en

# %%
# Save Ethereum dataframe to CSV
file_path = (".\dataframe_csv/ethereum_news.csv")
ethereum_df.to_csv(file_path, index=False, encoding='utf-8-sig')

# %%
# Concatenate dataframes
crypto_df = pd.concat([bitcoin_df, ethereum_df])
crypto_df.head()
# Out:
#                                                title  \
# 0  Ex-Party Producer Charged in $2.7 Million Bitc...
# 1  Everyone Has Crypto FOMO, but Does It Belong i...
# 2  If you’re a Russian YouTuber, how do you get p...
# 3  El Salvador turns to Binance for help on bitco...
# 4                         Why Isn't Bitcoin Booming?
#
#                                          description  \
# 0  Thomas Spieker’s clients included dark-web dru...
# 1  A growing array of investment options make it ...
# 2  Russian creators are shut off from the global ...
# 3  El Salvador is seeking support from cryptocurr...
# 4  "Bitcoin was seen by many of its libertarian-l...
#
#                                                 text        date language
# 0  Mr. Spiekers most prominent customer, whom he ...  2022-03-24       en
# 1  Other fund vehicles hold crypto directly, but ...  2022-03-24       en
# 2  When Russia invaded Ukraine, Niki Proshin was ...  2022-03-17       en
# 3  SAN SALVADOR, March 23 (Reuters) - El Salvador...  2022-03-23       en
# 4  "Bitcoin was seen by many of its libertarian-l...  2022-03-12       en

# %%
# Save combined dataframe to CSV
file_path = ("./dataframe_csv\crypto_news.csv")
crypto_df.to_csv(file_path, index=False, encoding='utf-8-sig')

# %%
# Create the sentiment scores DataFrame
def get_sentiment(score):
    """
    Calculates the sentiment based on the compound score.
    """
    result = 0  # Neutral by default
    if score >= 0.05:  # Positive
        result = 1
    elif score <= -0.05:  # Negative
        result = -1

    return result

# %%
# Sentiment scores dictionaries (Ethereum)
title_sent = {
    "title_compound": [],
    "title_pos": [],
    "title_neu": [],
    "title_neg": [],
    "title_sent": [],
}
text_sent = {
    "text_compound": [],
    "text_pos": [],
    "text_neu": [],
    "text_neg": [],
    "text_sent": [],
}

# Get sentiment for the text and the title
for index, row in ethereum_df.iterrows():
    try:
        # Sentiment scoring with VADER
        title_sentiment = analyzer.polarity_scores(row["title"])
        title_sent["title_compound"].append(title_sentiment["compound"])
        title_sent["title_pos"].append(title_sentiment["pos"])
        title_sent["title_neu"].append(title_sentiment["neu"])
        title_sent["title_neg"].append(title_sentiment["neg"])
        title_sent["title_sent"].append(get_sentiment(title_sentiment["compound"]))

        text_sentiment = analyzer.polarity_scores(row["text"])
        text_sent["text_compound"].append(text_sentiment["compound"])
        text_sent["text_pos"].append(text_sentiment["pos"])
        text_sent["text_neu"].append(text_sentiment["neu"])
        text_sent["text_neg"].append(text_sentiment["neg"])
        text_sent["text_sent"].append(get_sentiment(text_sentiment["compound"]))
    except AttributeError:
        pass

# Attaching sentiment columns to the Ethereum news dataframe
title_sentiment_df = pd.DataFrame(title_sent)
text_sentiment_df = pd.DataFrame(text_sent)
ethereum_df = ethereum_df.join(title_sentiment_df).join(text_sentiment_df)

# Inspect new dataframe 
ethereum_df.head()
# Out:
#                                                title  \
# 0  Ex-Party Producer Charged in $2.7 Million Bitc...
# 1  Everyone Has Crypto FOMO, but Does It Belong i...
# 2  If you’re a Russian YouTuber, how do you get p...
# 3  El Salvador turns to Binance for help on bitco...
# 4                         Why Isn't Bitcoin Booming?
#
#                                          description  \
# 0  Thomas Spieker’s clients included dark-web dru...
# 1  A growing array of investment options make it ...
# 2  Russian creators are shut off from the global ...
# 3  El Salvador is seeking support from cryptocurr...
# 4  "Bitcoin was seen by many of its libertarian-l...
#
#                                                 text        date language  \
# 0  Mr. Spiekers most prominent customer, whom he ...  2022-03-24       en
# 1  Other fund vehicles hold crypto directly, but ...  2022-03-24       en
# 2  When Russia invaded Ukraine, Niki Proshin was ...  2022-03-17       en
# 3  SAN SALVADOR, March 23 (Reuters) - El Salvador...  2022-03-23       en
# 4  "Bitcoin was seen by many of its libertarian-l...  2022-03-12       en
#
#    title_compound  title_pos  title_neu  title_neg  title_sent  text_compound  \
# 0         -0.2023      0.000      0.795      0.205          -1        -0.2280
# 1          0.0000      0.000      1.000      0.000           0        -0.1154
# 2          0.0000      0.000      1.000      0.000           0         0.0000
# 3          0.4019      0.213      0.787      0.000           1         0.4939
# 4          0.0000      0.000      1.000      0.000           0        -0.7713
#
#    text_pos  text_neu  text_neg  text_sent
# 0     0.072     0.831     0.097         -1
# 1     0.116     0.730     0.154         -1
# 2     0.000     1.000     0.000          0
# 3     0.123     0.877     0.000          1
# 4     0.000     0.831     0.169         -1

# %%
# Save ethereum dataframe to CSV
file_path = (".\dataframe_csv/eth_sentiment.csv")
ethereum_df.to_csv(file_path, index=False, encoding='utf-8-sig')

# %%
# Save ETH sentiment dataframe as JPEG
dfi.export(ethereum_df, './images\ethereum_df.jpg')

# %%
# Sentiment scores dictionaries (Bitcoin)
title_sent = {
    "title_compound": [],
    "title_pos": [],
    "title_neu": [],
    "title_neg": [],
    "title_sent": [],
}
text_sent = {
    "text_compound": [],
    "text_pos": [],
    "text_neu": [],
    "text_neg": [],
    "text_sent": [],
}

# Get sentiment for the text and the title
for index, row in bitcoin_df.iterrows():
    try:
        # Sentiment scoring with VADER
        title_sentiment = analyzer.polarity_scores(row["title"])
        title_sent["title_compound"].append(title_sentiment["compound"])
        title_sent["title_pos"].append(title_sentiment["pos"])
        title_sent["title_neu"].append(title_sentiment["neu"])
        title_sent["title_neg"].append(title_sentiment["neg"])
        title_sent["title_sent"].append(get_sentiment(title_sentiment["compound"]))

        text_sentiment = analyzer.polarity_scores(row["text"])
        text_sent["text_compound"].append(text_sentiment["compound"])
        text_sent["text_pos"].append(text_sentiment["pos"])
        text_sent["text_neu"].append(text_sentiment["neu"])
        text_sent["text_neg"].append(text_sentiment["neg"])
        text_sent["text_sent"].append(get_sentiment(text_sentiment["compound"]))
    except AttributeError:
        pass

# Attaching sentiment columns to the Ethereum news dataframe
title_sentiment_df = pd.DataFrame(title_sent)
text_sentiment_df = pd.DataFrame(text_sent)
bitcoin_df = bitcoin_df.join(title_sentiment_df).join(text_sentiment_df)

# Inspect new dataframe 
bitcoin_df.head()
# Out:
#                                                title  \
# 0  Ex-Party Producer Charged in $2.7 Million Bitc...
# 1  Everyone Has Crypto FOMO, but Does It Belong i...
# 2  If you’re a Russian YouTuber, how do you get p...
# 3  El Salvador turns to Binance for help on bitco...
# 4                         Why Isn't Bitcoin Booming?
#
#                                          description  \
# 0  Thomas Spieker’s clients included dark-web dru...
# 1  A growing array of investment options make it ...
# 2  Russian creators are shut off from the global ...
# 3  El Salvador is seeking support from cryptocurr...
# 4  "Bitcoin was seen by many of its libertarian-l...
#
#                                                 text        date language  \
# 0  Mr. Spiekers most prominent customer, whom he ...  2022-03-24       en
# 1  Other fund vehicles hold crypto directly, but ...  2022-03-24       en
# 2  When Russia invaded Ukraine, Niki Proshin was ...  2022-03-17       en
# 3  SAN SALVADOR, March 23 (Reuters) - El Salvador...  2022-03-23       en
# 4  "Bitcoin was seen by many of its libertarian-l...  2022-03-12       en
#
#    title_compound  title_pos  title_neu  title_neg  title_sent  text_compound  \
# 0         -0.2023      0.000      0.795      0.205          -1        -0.2280
# 1          0.0000      0.000      1.000      0.000           0        -0.1154
# 2          0.0000      0.000      1.000      0.000           0         0.0000
# 3          0.4019      0.213      0.787      0.000           1         0.4939
# 4          0.0000      0.000      1.000      0.000           0        -0.7713
#
#    text_pos  text_neu  text_neg  text_sent
# 0     0.072     0.831     0.097         -1
# 1     0.116     0.730     0.154         -1
# 2     0.000     1.000     0.000          0
# 3     0.123     0.877     0.000          1
# 4     0.000     0.831     0.169         -1

# %%
# Save BTH sentiment dataframe as CSV
file_path = (".\dataframe_csv/bitcoin_sentiment.csv")
bitcoin_df.to_csv(file_path, index=False, encoding='utf-8-sig')

# %%
# Save btc sentiment df as JPEG
dfi.export(bitcoin_df, '.\images/bitcoin_df.jpg')

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.plot(
    y=["title_sent", "text_sent"],
    kind="bar",
    title="Bitcoin News Title and Text Sentiment Comparisson",
    figsize=(10, 8),
    grid=True,
)

# Save plot as JPEG
plt.savefig(".\images/bitcoin_sentiment.jpg")

# %%
# Describe bitcoin dataframe
bitcoin_df.describe()
# Out:
#        title_compound  title_pos  title_neu  title_neg  title_sent  \
# count       20.000000  20.000000  20.000000  20.000000   20.000000
# mean        -0.020805   0.081450   0.815850   0.102650    0.050000
# std          0.264622   0.105278   0.184102   0.143588    0.759155
# min         -0.599400   0.000000   0.515000   0.000000   -1.000000
# 25%         -0.019300   0.000000   0.615000   0.000000   -0.250000
# 50%          0.000000   0.000000   0.823000   0.000000    0.000000
# 75%          0.165400   0.213750   1.000000   0.203500    1.000000
# max          0.401900   0.247000   1.000000   0.438000    1.000000
#
#        text_compound   text_pos  text_neu   text_neg  text_sent
# count      20.000000  20.000000  20.00000  20.000000  20.000000
# mean        0.110410   0.069850   0.88595   0.044300   0.250000
# std         0.396842   0.049143   0.07609   0.062683   0.910465
# min        -0.771300   0.000000   0.73000   0.000000  -1.000000
# 25%        -0.118550   0.036000   0.84825   0.000000  -1.000000
# 50%         0.223100   0.077500   0.87950   0.000000   1.000000
# 75%         0.430825   0.099500   0.93700   0.061750   1.000000
# max         0.636900   0.171000   1.00000   0.187000   1.000000

# %%
# Describe the Ethereum Sentiment
ethereum_df.plot(
    y=["title_sent", "text_sent"],
    kind="bar",
    title="Ethereum News Title and Text Sentiment Comparisson",
    figsize=(10, 8),
    grid=True,
)

# Save plot as JPEG
plt.savefig(".\images/eth_sentiment.jpg")

# %%
# Describe the Ethereum dataframe
ethereum_df.describe()
# Out:
#        title_compound  title_pos  title_neu  title_neg  title_sent  \
# count       20.000000  20.000000  20.000000  20.000000   20.000000
# mean        -0.020805   0.081450   0.815850   0.102650    0.050000
# std          0.264622   0.105278   0.184102   0.143588    0.759155
# min         -0.599400   0.000000   0.515000   0.000000   -1.000000
# 25%         -0.019300   0.000000   0.615000   0.000000   -0.250000
# 50%          0.000000   0.000000   0.823000   0.000000    0.000000
# 75%          0.165400   0.213750   1.000000   0.203500    1.000000
# max          0.401900   0.247000   1.000000   0.438000    1.000000
#
#        text_compound   text_pos  text_neu   text_neg  text_sent
# count      20.000000  20.000000  20.00000  20.000000  20.000000
# mean        0.110410   0.069850   0.88595   0.044300   0.250000
# std         0.396842   0.049143   0.07609   0.062683   0.910465
# min        -0.771300   0.000000   0.73000   0.000000  -1.000000
# 25%        -0.118550   0.036000   0.84825   0.000000  -1.000000
# 50%         0.223100   0.077500   0.87950   0.000000   1.000000
# 75%         0.430825   0.099500   0.93700   0.061750   1.000000
# max         0.636900   0.171000   1.00000   0.187000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A:
#
# Q: Which coin had the highest compound score?
#
# A:
#
# Q. Which coin had the highest positive score?
#
# A:

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from nltk.corpus import reuters, stopwords
from string import punctuation
import re

# %%
# Instantiate the lemmatizer (Bitcoin)
lemmatizer = WordNetLemmatizer()
article = bitcoin_df
print(article)
# Out:
#                                                 title  \
# 0   Ex-Party Producer Charged in $2.7 Million Bitc...
# 1   Everyone Has Crypto FOMO, but Does It Belong i...
# 2   If you’re a Russian YouTuber, how do you get p...
# 3   El Salvador turns to Binance for help on bitco...
# 4                          Why Isn't Bitcoin Booming?
# 5       Bitcoin rises 4.4 percent to $46499 - Reuters
# 6   Cryptoverse: Remember when bitcoin was 'anonym...
# 7   Cryptoverse: Bitcoin gains conflict currency c...
# 8   War Is Calling Crypto’s ‘Neutrality’ Into Ques...
# 9   Cryptocurrency Donations Pour Into Ukraine. Th...
# 10  Is the US Developing a Digital Dollar? This We...
# 11  Bitcoin and Ether Are Helping Fund Ukraine's R...
# 12    Cryptocurrencies in a time of war - Reuters.com
# 13  El Salvador postpones bitcoin bond issue, expe...
# 14  Cryptoverse: Bitcoin's scared of commitment, M...
# 15  U.S. company devises method to use coal waste ...
# 16  Bitcoin climbs to highest in almost three week...
# 17  El Salvador postpones bitcoin bond issue, expe...
# 18  Verdict against self-proclaimed Bitcoin invent...
# 19  Ukraine asking for bitcoin donations is bullis...
#
#                                           description  \
# 0   Thomas Spieker’s clients included dark-web dru...
# 1   A growing array of investment options make it ...
# 2   Russian creators are shut off from the global ...
# 3   El Salvador is seeking support from cryptocurr...
# 4   "Bitcoin was seen by many of its libertarian-l...
# 5   Bitcoin surged 4.41% to $46,499.29 at 22:07 GM...
# 6   Bitcoin just isn't anonymous enough for a grow...
# 7   Bitcoin has leapt since Russia's invasion of U...
# 8   War in Ukraine and Western sanctions against R...
# 9   Nonfungible Tidbits: All the bitcoin, cryptocu...
# 10  Nonfungible Tidbits: All the bitcoin, cryptocu...
# 11  Nearly $20 million has been raised in cryptocu...
# 12  Cryptocurrencies have been close to the headli...
# 13  El Salvador postponed an unprecedented issue o...
# 14  Bitcoin loves flirting with the mainstream. Bu...
# 15  The vast amounts of electricity needed to mine...
# 16  Bitcoin climbed on Tuesday to its highest in a...
# 17  El Salvador postponed an unprecedented issue o...
# 18  Self-proclaimed Bitcoin creator Craig Wright m...
# 19  "Still think bitcoin is not useful?" Fundstrat...
#
#                                                  text        date language  \
# 0   Mr. Spiekers most prominent customer, whom he ...  2022-03-24       en
# 1   Other fund vehicles hold crypto directly, but ...  2022-03-24       en
# 2   When Russia invaded Ukraine, Niki Proshin was ...  2022-03-17       en
# 3   SAN SALVADOR, March 23 (Reuters) - El Salvador...  2022-03-23       en
# 4   "Bitcoin was seen by many of its libertarian-l...  2022-03-12       en
# 5   March 27 (Reuters) - Bitcoin surged 4.41% to $...  2022-03-27       en
# 6   March 22 (Reuters) - Bitcoin just isn't anonym...  2022-03-22       en
# 7   March 1 (Reuters) - Bitcoin has leapt since Ru...  2022-03-01       en
# 8   Whose side is cryptocurrency on? If you had as...  2022-03-08       en
# 9   Getty\r\nWelcome to Nonfungible Tidbits. Our f...  2022-03-05       en
# 10  Here's what happened this week in the crypto w...  2022-03-19       en
# 11  Nurphoto/Getty\r\nAs Russia launched an invasi...  2022-02-28       en
# 12  LONDON, March 4 (Reuters) - Cryptocurrencies h...  2022-03-04       en
# 13  SAN SALVADOR, March 22 (Reuters) - El Salvador...  2022-03-22       en
# 14  March 15 (Reuters) - Bitcoin loves flirting wi...  2022-03-15       en
# 15  KENNERDELL, Pa., March 21 (Reuters) - The vast...  2022-03-21       en
# 16  LONDON, March 22 (Reuters) - Bitcoin climbed o...  2022-03-22       en
# 17  SAN SALVADOR, March 22 (Reuters) - El Salvador...  2022-03-22       en
# 18  <ul><li>\r\nSummary</li><li>\r\nLaw firms</li>...  2022-03-10       en
# 19  The Ukrainian government asking for donations ...  2022-03-01       en
#
#     title_compound  title_pos  title_neu  title_neg  title_sent  \
# 0          -0.2023      0.000      0.795      0.205          -1
# 1           0.0000      0.000      1.000      0.000           0
# 2           0.0000      0.000      1.000      0.000           0
# 3           0.4019      0.213      0.787      0.000           1
# 4           0.0000      0.000      1.000      0.000           0
# 5           0.0000      0.000      1.000      0.000           0
# 6           0.0000      0.000      1.000      0.000           0
# 7           0.0258      0.247      0.515      0.237           0
# 8          -0.5994      0.000      0.606      0.394          -1
# 9           0.0000      0.000      1.000      0.000           0
# 10          0.2023      0.130      0.870      0.000           1
# 11          0.2960      0.216      0.784      0.000           1
# 12         -0.5994      0.000      0.562      0.438          -1
# 13          0.2023      0.223      0.615      0.162           1
# 14         -0.0772      0.226      0.522      0.252          -1
# 15         -0.4215      0.000      0.797      0.203          -1
# 16          0.0000      0.000      1.000      0.000           0
# 17          0.2023      0.223      0.615      0.162           1
# 18          0.1531      0.151      0.849      0.000           1
# 19          0.0000      0.000      1.000      0.000           0
#
#     text_compound  text_pos  text_neu  text_neg  text_sent
# 0         -0.2280     0.072     0.831     0.097         -1
# 1         -0.1154     0.116     0.730     0.154         -1
# 2          0.0000     0.000     1.000     0.000          0
# 3          0.4939     0.123     0.877     0.000          1
# 4         -0.7713     0.000     0.831     0.169         -1
# 5          0.0000     0.000     1.000     0.000          0
# 6          0.6369     0.171     0.829     0.000          1
# 7          0.0000     0.000     1.000     0.000          0
# 8         -0.3182     0.055     0.854     0.091         -1
# 9         -0.6808     0.074     0.739     0.187         -1
# 10         0.4588     0.081     0.919     0.000          1
# 11         0.1280     0.048     0.952     0.000          1
# 12        -0.1280     0.000     0.954     0.046         -1
# 13         0.3182     0.089     0.860     0.052          1
# 14         0.3182     0.098     0.864     0.038          1
# 15         0.4588     0.118     0.882     0.000          1
# 16         0.3400     0.068     0.932     0.000          1
# 17         0.3182     0.089     0.860     0.052          1
# 18         0.4215     0.091     0.909     0.000          1
# 19         0.5574     0.104     0.896     0.000          1

# %%
# Instantiate the lemmatizer (Bitcoin)
lemmatizer = WordNetLemmatizer()
article = ethereum_df
print(article)
# Out:
#                                                 title  \
# 0   Ex-Party Producer Charged in $2.7 Million Bitc...
# 1   Everyone Has Crypto FOMO, but Does It Belong i...
# 2   If you’re a Russian YouTuber, how do you get p...
# 3   El Salvador turns to Binance for help on bitco...
# 4                          Why Isn't Bitcoin Booming?
# 5       Bitcoin rises 4.4 percent to $46499 - Reuters
# 6   Cryptoverse: Remember when bitcoin was 'anonym...
# 7   Cryptoverse: Bitcoin gains conflict currency c...
# 8   War Is Calling Crypto’s ‘Neutrality’ Into Ques...
# 9   Cryptocurrency Donations Pour Into Ukraine. Th...
# 10  Is the US Developing a Digital Dollar? This We...
# 11  Bitcoin and Ether Are Helping Fund Ukraine's R...
# 12    Cryptocurrencies in a time of war - Reuters.com
# 13  El Salvador postpones bitcoin bond issue, expe...
# 14  Cryptoverse: Bitcoin's scared of commitment, M...
# 15  U.S. company devises method to use coal waste ...
# 16  Bitcoin climbs to highest in almost three week...
# 17  El Salvador postpones bitcoin bond issue, expe...
# 18  Verdict against self-proclaimed Bitcoin invent...
# 19  Ukraine asking for bitcoin donations is bullis...
#
#                                           description  \
# 0   Thomas Spieker’s clients included dark-web dru...
# 1   A growing array of investment options make it ...
# 2   Russian creators are shut off from the global ...
# 3   El Salvador is seeking support from cryptocurr...
# 4   "Bitcoin was seen by many of its libertarian-l...
# 5   Bitcoin surged 4.41% to $46,499.29 at 22:07 GM...
# 6   Bitcoin just isn't anonymous enough for a grow...
# 7   Bitcoin has leapt since Russia's invasion of U...
# 8   War in Ukraine and Western sanctions against R...
# 9   Nonfungible Tidbits: All the bitcoin, cryptocu...
# 10  Nonfungible Tidbits: All the bitcoin, cryptocu...
# 11  Nearly $20 million has been raised in cryptocu...
# 12  Cryptocurrencies have been close to the headli...
# 13  El Salvador postponed an unprecedented issue o...
# 14  Bitcoin loves flirting with the mainstream. Bu...
# 15  The vast amounts of electricity needed to mine...
# 16  Bitcoin climbed on Tuesday to its highest in a...
# 17  El Salvador postponed an unprecedented issue o...
# 18  Self-proclaimed Bitcoin creator Craig Wright m...
# 19  "Still think bitcoin is not useful?" Fundstrat...
#
#                                                  text        date language  \
# 0   Mr. Spiekers most prominent customer, whom he ...  2022-03-24       en
# 1   Other fund vehicles hold crypto directly, but ...  2022-03-24       en
# 2   When Russia invaded Ukraine, Niki Proshin was ...  2022-03-17       en
# 3   SAN SALVADOR, March 23 (Reuters) - El Salvador...  2022-03-23       en
# 4   "Bitcoin was seen by many of its libertarian-l...  2022-03-12       en
# 5   March 27 (Reuters) - Bitcoin surged 4.41% to $...  2022-03-27       en
# 6   March 22 (Reuters) - Bitcoin just isn't anonym...  2022-03-22       en
# 7   March 1 (Reuters) - Bitcoin has leapt since Ru...  2022-03-01       en
# 8   Whose side is cryptocurrency on? If you had as...  2022-03-08       en
# 9   Getty\r\nWelcome to Nonfungible Tidbits. Our f...  2022-03-05       en
# 10  Here's what happened this week in the crypto w...  2022-03-19       en
# 11  Nurphoto/Getty\r\nAs Russia launched an invasi...  2022-02-28       en
# 12  LONDON, March 4 (Reuters) - Cryptocurrencies h...  2022-03-04       en
# 13  SAN SALVADOR, March 22 (Reuters) - El Salvador...  2022-03-22       en
# 14  March 15 (Reuters) - Bitcoin loves flirting wi...  2022-03-15       en
# 15  KENNERDELL, Pa., March 21 (Reuters) - The vast...  2022-03-21       en
# 16  LONDON, March 22 (Reuters) - Bitcoin climbed o...  2022-03-22       en
# 17  SAN SALVADOR, March 22 (Reuters) - El Salvador...  2022-03-22       en
# 18  <ul><li>\r\nSummary</li><li>\r\nLaw firms</li>...  2022-03-10       en
# 19  The Ukrainian government asking for donations ...  2022-03-01       en
#
#     title_compound  title_pos  title_neu  title_neg  title_sent  \
# 0          -0.2023      0.000      0.795      0.205          -1
# 1           0.0000      0.000      1.000      0.000           0
# 2           0.0000      0.000      1.000      0.000           0
# 3           0.4019      0.213      0.787      0.000           1
# 4           0.0000      0.000      1.000      0.000           0
# 5           0.0000      0.000      1.000      0.000           0
# 6           0.0000      0.000      1.000      0.000           0
# 7           0.0258      0.247      0.515      0.237           0
# 8          -0.5994      0.000      0.606      0.394          -1
# 9           0.0000      0.000      1.000      0.000           0
# 10          0.2023      0.130      0.870      0.000           1
# 11          0.2960      0.216      0.784      0.000           1
# 12         -0.5994      0.000      0.562      0.438          -1
# 13          0.2023      0.223      0.615      0.162           1
# 14         -0.0772      0.226      0.522      0.252          -1
# 15         -0.4215      0.000      0.797      0.203          -1
# 16          0.0000      0.000      1.000      0.000           0
# 17          0.2023      0.223      0.615      0.162           1
# 18          0.1531      0.151      0.849      0.000           1
# 19          0.0000      0.000      1.000      0.000           0
#
#     text_compound  text_pos  text_neu  text_neg  text_sent
# 0         -0.2280     0.072     0.831     0.097         -1
# 1         -0.1154     0.116     0.730     0.154         -1
# 2          0.0000     0.000     1.000     0.000          0
# 3          0.4939     0.123     0.877     0.000          1
# 4         -0.7713     0.000     0.831     0.169         -1
# 5          0.0000     0.000     1.000     0.000          0
# 6          0.6369     0.171     0.829     0.000          1
# 7          0.0000     0.000     1.000     0.000          0
# 8         -0.3182     0.055     0.854     0.091         -1
# 9         -0.6808     0.074     0.739     0.187         -1
# 10         0.4588     0.081     0.919     0.000          1
# 11         0.1280     0.048     0.952     0.000          1
# 12        -0.1280     0.000     0.954     0.046         -1
# 13         0.3182     0.089     0.860     0.052          1
# 14         0.3182     0.098     0.864     0.038          1
# 15         0.4588     0.118     0.882     0.000          1
# 16         0.3400     0.068     0.932     0.000          1
# 17         0.3182     0.089     0.860     0.052          1
# 18         0.4215     0.091     0.909     0.000          1
# 19         0.5574     0.104     0.896     0.000          1

# %%
# Create a list of stopwords
sw = set(stopwords.words('english'))

# Expand the default stopwords list if necessary
sw_addons = { "a4", "ab", "able", "about", "above", "abst", "ac", "accordance", "according", "accordingly", "across", "act", 
              "actually", "ad", "added", "adj", "ae", "af", "affected", "affecting", "after", "afterwards", "ag", "again", "against", "ah", "ain", "aj", "al", "all", "allow", "allows", "almost", 
              "alone", "along", "already", "also", "although", "always", "am", "among", "amongst", "amoungst", "amount", "an", "and", "announce", "another", "any", "anybody", "anyhow", "anymore", 
              "anyone", "anyway", "anyways", "anywhere", "ao", "ap", "apart", "apparently", "appreciate", "approximately", "ar", "are", "aren", "arent", "arise", "around", "as", "aside", "ask", 
              "asking", "at", "au", "auth", "av", "available", "aw", "away", "awfully", "ax", "ay", "az", "b", "B", "b1", "b2", "b3", "ba", "back", "bc", "bd", "be", "became", "been", "before", 
              "beforehand", "beginnings", "behind", "below", "beside", "besides", "best", "between", "beyond", "bi", "bill", "biol", "bj", "bk", "bl", "bn", "both", "bottom", "bp", "br", "brief", 
              "briefly", "bs", "bt", "bu", "but", "bx", "by", "c", "C", "c1", "c2", "c3", "ca", "call", "came", "can", "cannot", "cant", "cc", "cd", "ce", "certain", "certainly", "cf", "cg", "ch", 
              "ci", "cit", "cj", "cl", "clearly", "cm", "cn", "co", "com", "come", "comes", "con", "concerning", "consequently", "consider", "considering", "could", "couldn", "couldnt", "course", 
              "cp", "cq", "cr", "cry", "cs", "ct", "cu", "cv", "cx", "cy", "cz", "d", "D", "d2", "da", "date", "dc", "dd", "de", "definitely", "describe", "described", "despite", "detail", "df", 
              "di", "did", "didn", "dj", "dk", "dl", "do", "does", "doesn", "doing", "don", "done", "down", "downwards", "dp", "dr", "ds", "dt", "du", "due", "during", "dx", "dy", "e", "E", "e2", 
              "e3", "ea", "each", "ec", "ed", "edu", "ee", "ef", "eg", "ei", "eight", "eighty", "either", "ej", "el", "eleven", "else", "elsewhere", "em", "en", "end", "ending", "enough", "entirely", 
              "eo", "ep", "eq", "er", "es", "especially", "est", "et", "et-al", "etc", "eu", "ev", "even", "ever", "every", "everybody", "everyone", "everything", "everywhere", "ex", "exactly", 
              "example", "except", "ey", "f", "F", "f2", "fa", "far", "fc", "few", "ff", "fi", "fifteen", "fifth", "fify", "fill", "find", "fire", "five", "fix", "fj", "fl", "fn", "fo", "followed", 
              "following", "follows", "for", "former", "formerly", "forth", "forty", "found", "four", "fr", "from", "front", "fs", "ft", "fu", "full", "further", "furthermore", "fy", "g", "G", "ga", 
              "gave", "ge", "get", "gets", "getting", "gi", "give", "given", "gives", "giving", "gj", "gl", "go", "goes", "going", "gone", "got", "gotten", "gr", "greetings", "gs", "gy", "h", "H", 
              "h2", "h3", "had", "hadn", "happens", "hardly", "has", "hasn", "hasnt", "have", "haven", "having", "he", "hed", "hello", "help", "hence", "here", "hereafter", "hereby", "herein", "heres", 
              "hereupon", "hes", "hh", "hi", "hid", "hither", "hj", "ho", "hopefully", "how", "howbeit", "however", "hr", "hs", "http", "hu", "hundred", "hy", "i2", "i3", "i4", "i6", "i7", 
              "i8", "ia", "ib", "ibid", "ic", "id", "ie", "if", "ig", "ignored", "ih", "ii", "ij", "il", "im", "immediately", "in", "inasmuch", "inc", "indeed", "index", "indicate", "indicated", 
              "indicates", "information", "inner", "insofar", "instead", "interest", "into", "inward", "io", "ip", "iq", "ir", "is", "isn", "it", "itd", "its", "iv", "ix", "iy", "iz", "j", "J", 
              "jj", "jr", "js", "jt", "ju", "just", "k", "K", "ke", "keep", "keeps", "kept", "kg", "kj", "km", "ko", "l", "L", "l2", "la", "largely", "last", "lately", "later", "latter", "latterly", 
              "lb", "lc", "le", "least", "les", "less", "lest", "let", "lets", "lf", "like", "liked", "likely", "line", "little", "lj", "ll", "ln", "lo", "look", "looking", "looks", "los", "lr", 
              "ls", "lt", "ltd", "m", "M", "m2", "ma", "made", "mainly", "make", "makes", "many", "may", "maybe", "me", "meantime", "meanwhile", "merely", "mg", "might", "mightn", "mill", "million", 
              "mine", "miss", "ml", "mn", "mo", "more", "moreover", "most", "mostly", "move", "mr", "mrs", "ms", "mt", "mu", "much", "mug", "must", "mustn", "my", "n", "N", "n2", "na", "name", 
              "namely", "nay", "nc", "nd", "ne", "near", "nearly", "necessarily", "neither", "nevertheless", "new", "next", "ng", "ni", "nine", "ninety", "nj", "nl", "nn", "no", "nobody", 
              "non", "none", "nonetheless", "noone", "nor", "normally", "nos", "not", "noted", "novel", "now", "nowhere", "nr", "ns", "nt", "ny", "o", "O", "oa", "ob", "obtain", "obtained", 
              "obviously", "oc", "od", "of", "off", "often", "og", "oh", "oi", "oj", "ok", "okay", "ol", "old", "om", "omitted", "on", "once", "one", "ones", "only", "onto", "oo", "op", "oq", 
              "or", "ord", "os", "ot", "otherwise", "ou", "ought", "our", "out", "outside", "over", "overall", "ow", "owing", "own", "ox", "oz", "p", "P", "p1", "p2", "p3", "page", "pagecount", 
              "pages", "par", "part", "particular", "particularly", "pas", "past", "pc", "pd", "pe", "per", "perhaps", "pf", "ph", "pi", "pj", "pk", "pl", "placed", "please", "plus", "pm", "pn", 
              "po", "poorly", "pp", "pq", "pr", "predominantly", "presumably", "previously", "primarily", "probably", "promptly", "proud", "provides", "ps", "pt", "pu", "put", "py", "q", "Q", "qj", 
              "qu", "que", "quickly", "quite", "qv", "r", "R", "r2", "ra", "ran", "rather", "rc", "rd", "re", "readily", "really", "reasonably", "recent", "recently", "ref", "refs", "regarding", 
              "regardless", "regards", "related", "relatively", "research-articl", "respectively", "resulted", "resulting", "results", "rf", "rh", "ri", "right", "rj", "rl", "rm", "rn", "ro", 
              "rq", "rr", "rs", "rt", "ru", "run", "rv", "ry", "s", "S", "s2", "sa", "said", "saw", "say", "saying", "says", "sc", "sd", "se", "sec", "second", "secondly", "section", "seem", 
              "seemed", "seeming", "seems", "seen", "sent", "seven", "several", "sf", "shall", "shan", "shed", "shes", "show", "showed", "shown", "showns", "shows", "si", "side", "since", "sincere", 
              "six", "sixty", "sj", "sl", "slightly", "sm", "sn", "so", "some", "somehow", "somethan", "sometime", "sometimes", "somewhat", "somewhere", "soon", "sorry", "sp", "specifically", 
              "specified", "specify", "specifying", "sq", "sr", "ss", "st", "still", "stop", "strongly", "sub", "substantially", "successfully", "such", "sufficiently", "suggest", "sup", "sure", 
              "sy", "sz", "t", "T", "t1", "t2", "t3", "take", "taken", "taking", "tb", "tc", "td", "te", "tell", "ten", "tends", "tf", "th", "than", "thank", "thanks", "thanx", "that", "thats", 
              "the", "their", "theirs", "them", "themselves", "then", "thence", "there", "thereafter", "thereby", "thered", "therefore", "therein", "thereof", "therere", "theres", "thereto", 
              "thereupon", "these", "they", "theyd", "theyre", "thickv", "thin", "think", "third", "this", "thorough", "thoroughly", "those", "thou", "though", "thoughh", "thousand", "three", 
              "throug", "through", "throughout", "thru", "thus", "ti", "til", "tip", "tj", "tl", "tm", "tn", "to", "together", "too", "took", "top", "toward", "towards", "tp", "tq", "tr", 
              "tried", "tries", "truly", "try", "trying", "ts", "tt", "tv", "twelve", "twenty", "twice", "two", "tx", "u", "U", "u201d", "ue", "ui", "uj", "uk", "um", "un", "under", 
              "unfortunately", "unless", "unlike", "unlikely", "until", "unto", "uo", "up", "upon", "ups", "ur", "us", "used", "useful", "usefully", "usefulness", "using", "usually", "ut", "v", 
              "V", "va", "various", "vd", "ve", "very", "via", "viz", "vj", "vo", "vol", "vols", "volumtype", "vq", "vs", "vt", "vu", "w", "W", "wa", "was", "wasn", "wasnt", "way", "we", "wed", 
              "welcome", "well", "well-b", "went", "were", "weren", "werent", "what", "whatever", "whats", "when", "whence", "whenever", "where", "whereafter", "whereas", "whereby", "wherein", 
              "wheres", "whereupon", "wherever", "whether", "which", "while", "whim", "whither", "who", "whod", "whoever", "whole", "whom", "whomever", "whos", "whose", "why", "wi", "widely", 
              "with", "within", "without", "wo", "won", "wonder", "wont", "would", "wouldn", "wouldnt", "www", "x", "X", "x1", "x2", "x3", "xf", "xi", "xj", "xk", "xl", "xn", "xo", "xs", "xt", 
              "xv", "xx", "y", "Y", "y2", "yes", "yet", "yj", "yl", "you", "youd", "your", "youre", "yours", "yr", "ys", "yt", "z", "Z", "zero", "zi", "zz"}
stop = set(list(sw)+list(sw_addons))

# %%
# Define function
def tokenizer(text):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', article)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in lem if word.lower() not in sw]
    return tokens

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    ## Define and apply the regex parameters
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)
    
    # Create a tokenized list of the words
    words = word_tokenize(text)
    
    # Convert the words to lowercase
    words = list(filter(lambda w: w.lower(), words))
    
    # Remove the punctuation from text
    words = list(filter(lambda t: t not in punctuation, words))
    
    # Remove the stop words
    words = list(filter(lambda t: t.lower() not in stop, words))
    
    # Lemmatize words into root words
    tokens = [lemmatizer.lemmatize(word) for word in words]

    return tokens

# %%
# Create a new tokens column for Bitcoin
bitcoin_df["tokens"] = bitcoin_df.text.apply(tokenizer)
bitcoin_df.head()
# Out:
#                                                title  \
# 0  Ex-Party Producer Charged in $2.7 Million Bitc...
# 1  Everyone Has Crypto FOMO, but Does It Belong i...
# 2  If you’re a Russian YouTuber, how do you get p...
# 3  El Salvador turns to Binance for help on bitco...
# 4                         Why Isn't Bitcoin Booming?
#
#                                          description  \
# 0  Thomas Spieker’s clients included dark-web dru...
# 1  A growing array of investment options make it ...
# 2  Russian creators are shut off from the global ...
# 3  El Salvador is seeking support from cryptocurr...
# 4  "Bitcoin was seen by many of its libertarian-l...
#
#                                                 text        date language  \
# 0  Mr. Spiekers most prominent customer, whom he ...  2022-03-24       en
# 1  Other fund vehicles hold crypto directly, but ...  2022-03-24       en
# 2  When Russia invaded Ukraine, Niki Proshin was ...  2022-03-17       en
# 3  SAN SALVADOR, March 23 (Reuters) - El Salvador...  2022-03-23       en
# 4  "Bitcoin was seen by many of its libertarian-l...  2022-03-12       en
#
#    title_compound  title_pos  title_neu  title_neg  title_sent  text_compound  \
# 0         -0.2023      0.000      0.795      0.205          -1        -0.2280
# 1          0.0000      0.000      1.000      0.000           0        -0.1154
# 2          0.0000      0.000      1.000      0.000           0         0.0000
# 3          0.4019      0.213      0.787      0.000           1         0.4939
# 4          0.0000      0.000      1.000      0.000           0        -0.7713
#
#    text_pos  text_neu  text_neg  text_sent  \
# 0     0.072     0.831     0.097         -1
# 1     0.116     0.730     0.154         -1
# 2     0.000     1.000     0.000          0
# 3     0.123     0.877     0.000          1
# 4     0.000     0.831     0.169         -1
#
#                                               tokens
# 0  [Mr., Spiekers, prominent, customer, whale, cl...
# 1  [fund, vehicle, hold, crypto, directly, grappl...
# 2  [Russia, invaded, Ukraine, Niki, Proshin, year...
# 3  [SAN, SALVADOR, March, 23, Reuters, Salvador, ...
# 4  [``, Bitcoin, libertarian-leaning, fan, kind, ...

# %%
# Save dataframe to CSV
file_path = (".\dataframe_csv/btc_with_token_column.csv")
bitcoin_df.to_csv(file_path, index=False, encoding='utf-8-sig')

# %%
# Create a new tokens column for Ethereum
ethereum_df["tokens"] = ethereum_df.text.apply(tokenizer)
ethereum_df.head()
# Out:
#                                                title  \
# 0  Ex-Party Producer Charged in $2.7 Million Bitc...
# 1  Everyone Has Crypto FOMO, but Does It Belong i...
# 2  If you’re a Russian YouTuber, how do you get p...
# 3  El Salvador turns to Binance for help on bitco...
# 4                         Why Isn't Bitcoin Booming?
#
#                                          description  \
# 0  Thomas Spieker’s clients included dark-web dru...
# 1  A growing array of investment options make it ...
# 2  Russian creators are shut off from the global ...
# 3  El Salvador is seeking support from cryptocurr...
# 4  "Bitcoin was seen by many of its libertarian-l...
#
#                                                 text        date language  \
# 0  Mr. Spiekers most prominent customer, whom he ...  2022-03-24       en
# 1  Other fund vehicles hold crypto directly, but ...  2022-03-24       en
# 2  When Russia invaded Ukraine, Niki Proshin was ...  2022-03-17       en
# 3  SAN SALVADOR, March 23 (Reuters) - El Salvador...  2022-03-23       en
# 4  "Bitcoin was seen by many of its libertarian-l...  2022-03-12       en
#
#    title_compound  title_pos  title_neu  title_neg  title_sent  text_compound  \
# 0         -0.2023      0.000      0.795      0.205          -1        -0.2280
# 1          0.0000      0.000      1.000      0.000           0        -0.1154
# 2          0.0000      0.000      1.000      0.000           0         0.0000
# 3          0.4019      0.213      0.787      0.000           1         0.4939
# 4          0.0000      0.000      1.000      0.000           0        -0.7713
#
#    text_pos  text_neu  text_neg  text_sent  \
# 0     0.072     0.831     0.097         -1
# 1     0.116     0.730     0.154         -1
# 2     0.000     1.000     0.000          0
# 3     0.123     0.877     0.000          1
# 4     0.000     0.831     0.169         -1
#
#                                               tokens
# 0  [Mr., Spiekers, prominent, customer, whale, cl...
# 1  [fund, vehicle, hold, crypto, directly, grappl...
# 2  [Russia, invaded, Ukraine, Niki, Proshin, year...
# 3  [SAN, SALVADOR, March, 23, Reuters, Salvador, ...
# 4  [``, Bitcoin, libertarian-leaning, fan, kind, ...

# %%
# Save dataframe to CSV
file_path = (".\dataframe_csv/eth_with_token_column.csv")
ethereum_df.to_csv(file_path, index=False, encoding='utf-8-sig')

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
N = 2
grams = ngrams(tokenizer(bitcoin_df.text.str.cat()), N)
Counter(grams).most_common(20)
# Out:
# [(('Reuters', 'Bitcoin'), 5),
#  (('char', 'March'), 4),
#  (('March', '22'), 4),
#  (('22', 'Reuters'), 4),
#  (('char', 'SAN'), 3),
#  (('SAN', 'SALVADOR'), 3),
#  (('SALVADOR', 'March'), 3),
#  (('Reuters', 'Salvador'), 3),
#  (('Russia', "'s"), 3),
#  (('Russia', 'invaded'), 2),
#  (('invaded', 'Ukraine'), 2),
#  (("'s", 'invasion'), 2),
#  (('invasion', 'Ukraine'), 2),
#  (('Getty', 'Nonfungible'), 2),
#  (('Nonfungible', 'Tidbits'), 2),
#  (('char', 'LONDON'), 2),
#  (('LONDON', 'March'), 2),
#  (('Salvador', 'postponed'), 2),
#  (('postponed', 'unprecedented'), 2),
#  (('unprecedented', 'issue'), 2)]

# %%
# Generate the Ethereum N-grams where N=2
N = 2
grams = ngrams(tokenizer(ethereum_df.text.str.cat()), N)
Counter(grams).most_common(20)
# Out:
# [(('Reuters', 'Bitcoin'), 5),
#  (('char', 'March'), 4),
#  (('March', '22'), 4),
#  (('22', 'Reuters'), 4),
#  (('char', 'SAN'), 3),
#  (('SAN', 'SALVADOR'), 3),
#  (('SALVADOR', 'March'), 3),
#  (('Reuters', 'Salvador'), 3),
#  (('Russia', "'s"), 3),
#  (('Russia', 'invaded'), 2),
#  (('invaded', 'Ukraine'), 2),
#  (("'s", 'invasion'), 2),
#  (('invasion', 'Ukraine'), 2),
#  (('Getty', 'Nonfungible'), 2),
#  (('Nonfungible', 'Tidbits'), 2),
#  (('char', 'LONDON'), 2),
#  (('LONDON', 'March'), 2),
#  (('Salvador', 'postponed'), 2),
#  (('postponed', 'unprecedented'), 2),
#  (('unprecedented', 'issue'), 2)]

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
btc_tokens = tokenizer(bitcoin_df.text.str.cat())
token_count(btc_tokens, N = 10)
# Out:
# [('char', 20),
#  ('Bitcoin', 11),
#  ('March', 10),
#  ('Reuters', 10),
#  ('crypto', 7),
#  ('Russia', 7),
#  ('Ukraine', 6),
#  ('week', 6),
#  ('bitcoin', 5),
#  ("'s", 5)]

# %%
# Use token_count to get the top 10 words for Ethereum
eth_tokens = tokenizer(ethereum_df.text.str.cat())
token_count(eth_tokens, N = 10)
# Out:
# [('char', 20),
#  ('Bitcoin', 11),
#  ('March', 10),
#  ('Reuters', 10),
#  ('crypto', 7),
#  ('Russia', 7),
#  ('Ukraine', 6),
#  ('week', 6),
#  ('bitcoin', 5),
#  ("'s", 5)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
word_cloud = WordCloud().generate(' '.join(btc_tokens))
plt.imshow(word_cloud)
plt.title("Bitcoin Word Cloud", fontdict={'fontsize':25})

# Save as jpeg
plt.savefig(".\images/btc_cloud.jpg")

# %%
# Generate the Ethereum word cloud
word_cloud = WordCloud().generate(' '.join(eth_tokens))
plt.imshow(word_cloud)
plt.title("Ethereum Word Cloud", fontdict={'fontsize':25})

# Save as jpeg
plt.savefig(".\images/eth_cloud.jpg")

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
bitcoin_NER = bitcoin_df["text"].str.cat()

# %%
# Run the NER processor on all of the text
doc = nlp(bitcoin_NER)

# Add a title to the document
doc.user_data["title"]="Bitcoin NER"

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Spiekers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  most prominent customer, whom he described as his whale client, was the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Eastern European
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  organized crime member, prosecutors said. Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Spieker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  laundered $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     620,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Grayscale Bitcoin Trust
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , the largest Bitcoin veh… [+2273 chars]When
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  invaded
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ukraine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Niki Proshin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was already
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  into making a living as a vlogger — he had a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     YouTube
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  channel, a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TikTok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  channel, and an
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Instagram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . He also ran an online
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  club for a… [+5883 chars]SAN SALVADOR,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March 23
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) -
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El Salvador
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is seeking support from cryptocurrency exchange
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Binance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  for its implementation of bitcoin as legal tender and the issuance of bitcoin bonds, the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Central
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# … [+1109 chars]&quot;Bitcoin was seen by many of its libertarian-leaning fans as a kind of doomsday insurance,&quot; argues a columnist in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the New York Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , &quot;a form of 'digital gold' that would be a source of stability as … [+3914 chars]March
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     27
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Bitcoin surged
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4.41%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  to $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     46,499.29
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  at 22:07 GMT on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1;

# %%
# List all Entities
for i in doc.ents:
    print(i.text, i.label_)
# Out:
# Spiekers PERSON
# Eastern European NORP
# Spieker PERSON
# 620,000 MONEY
# Grayscale Bitcoin Trust ORG
# Russia GPE
# Ukraine GPE
# Niki Proshin PERSON
# a year DATE
# YouTube ORG
# TikTok ORG
# Instagram ORG
# Russian NORP
# March 23 DATE
# Reuters ORG
# El Salvador GPE
# Binance PERSON
# Central ORG
# the New York Times ORG
# 27 CARDINAL
# Reuters ORG
# 4.41% PERCENT
# 46,499.29 MONEY
# Sunday DATE
# 1,963.64 MONEY
# Bitcoin PERSON
# 41.1% PERCENT
# Reuters ORG
# Reuters ORG
# Russia GPE
# Ukraine GPE
# Satoshi Nakamoto PERSON
# 2008 DATE
# Nonfungible Tidbits PERSON
# this week DATE
# Russia GPE
# Ukraine GPE
# Ukrainians NORP
# Russian NORP
# +3275 ORG
# this week DATE
# Getty
# Welcome to ORG
# Nonfungible Tidbits PERSON
# weekly DATE
# this week DATE
# Getty GPE
# Russia GPE
# last Thursday DATE
# Ukranian NORP
# Mexico City GPE
# Telegr ORG
# March 4 DATE
# Reuters ORG
# Russia GPE
# Ukraine GPE
# Russia GPE
# March 22 DATE
# Reuters ORG
# El Salvador GPE
# last week DATE
# finan GPE
# Reuters ORG
# U.S. GPE
# Joe Biden PERSON
# chars]KENNERDELL ORG
# Pa. GPE
# March 21 DATE
# Reuters ORG
# March 22 DATE
# Reuters ORG
# Tuesday DATE
# almost three weeks DATE
# Russia GPE
# Ukraine GPE
# March 22 DATE
# Reuters ORG
# El Salvador GPE
# last week DATE
# finan GPE
# Summary</li><li> WORK_OF_ART
# Law firms</li><li>
#  PERSON
# documents</li></ul GPE
# Ukrainian NORP
# Tom Lee PERSON
# Ukraine GPE

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
ethereum_NER = ethereum_df["text"].str.cat()

# %%
# Run the NER processor on all of the text
doc = nlp(ethereum_NER)

# Add a title to the document
doc.user_data["title"]="Ethereum NER"

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Spiekers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  most prominent customer, whom he described as his whale client, was the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Eastern European
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  organized crime member, prosecutors said. Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Spieker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  laundered $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     620,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Grayscale Bitcoin Trust
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , the largest Bitcoin veh… [+2273 chars]When
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  invaded
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ukraine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Niki Proshin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was already
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  into making a living as a vlogger — he had a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     YouTube
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  channel, a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TikTok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  channel, and an
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Instagram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . He also ran an online
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  club for a… [+5883 chars]SAN SALVADOR,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March 23
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) -
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El Salvador
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is seeking support from cryptocurrency exchange
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Binance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  for its implementation of bitcoin as legal tender and the issuance of bitcoin bonds, the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Central
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# … [+1109 chars]&quot;Bitcoin was seen by many of its libertarian-leaning fans as a kind of doomsday insurance,&quot; argues a columnist in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the New York Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , &quot;a form of 'digital gold' that would be a source of stability as … [+3914 chars]March
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     27
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Bitcoin surged
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4.41%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  to $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     46,499.29
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  at 22:07 GMT on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1

# %%
# List all Entities
for i in doc.ents:
    print(i.text, i.label_)
# Out:
# Spiekers PERSON
# Eastern European NORP
# Spieker PERSON
# 620,000 MONEY
# Grayscale Bitcoin Trust ORG
# Russia GPE
# Ukraine GPE
# Niki Proshin PERSON
# a year DATE
# YouTube ORG
# TikTok ORG
# Instagram ORG
# Russian NORP
# March 23 DATE
# Reuters ORG
# El Salvador GPE
# Binance PERSON
# Central ORG
# the New York Times ORG
# 27 CARDINAL
# Reuters ORG
# 4.41% PERCENT
# 46,499.29 MONEY
# Sunday DATE
# 1,963.64 MONEY
# Bitcoin PERSON
# 41.1% PERCENT
# Reuters ORG
# Reuters ORG
# Russia GPE
# Ukraine GPE
# Satoshi Nakamoto PERSON
# 2008 DATE
# Nonfungible Tidbits PERSON
# this week DATE
# Russia GPE
# Ukraine GPE
# Ukrainians NORP
# Russian NORP
# +3275 ORG
# this week DATE
# Getty
# Welcome to ORG
# Nonfungible Tidbits PERSON
# weekly DATE
# this week DATE
# Getty GPE
# Russia GPE
# last Thursday DATE
# Ukranian NORP
# Mexico City GPE
# Telegr ORG
# March 4 DATE
# Reuters ORG
# Russia GPE
# Ukraine GPE
# Russia GPE
# March 22 DATE
# Reuters ORG
# El Salvador GPE
# last week DATE
# finan GPE
# Reuters ORG
# U.S. GPE
# Joe Biden PERSON
# chars]KENNERDELL ORG
# Pa. GPE
# March 21 DATE
# Reuters ORG
# March 22 DATE
# Reuters ORG
# Tuesday DATE
# almost three weeks DATE
# Russia GPE
# Ukraine GPE
# March 22 DATE
# Reuters ORG
# El Salvador GPE
# last week DATE
# finan GPE
# Summary</li><li> WORK_OF_ART
# Law firms</li><li>
#  PERSON
# documents</li></ul GPE
# Ukrainian NORP
# Tom Lee PERSON
# Ukraine GPE

# %% [markdown]
# ### Correlating Returns
# #### Ethereum

# %%
api = tradeapi.REST(alpaca_api_key, alpaca_secret_key, api_version='v2')

# %%
# Retrieve ETH stock data
df = api.get_bars("ETH", TimeFrame(45, TimeFrameUnit.Minute), "2021-03-27", "2022-03-27", adjustment='raw').df
df.head(10)
# Out:
#                             open     high     low   close  volume  \
# timestamp
# 2021-03-29 13:30:00+00:00  27.92  28.4600  27.920  28.010   39271
# 2021-03-29 14:15:00+00:00  27.99  28.0688  27.640  27.655   25360
# 2021-03-29 15:00:00+00:00  27.71  27.8200  27.580  27.660   26955
# 2021-03-29 15:45:00+00:00  27.63  27.6700  27.365  27.470   38054
# 2021-03-29 16:30:00+00:00  27.50  27.8400  27.500  27.700   27774
# 2021-03-29 17:15:00+00:00  27.68  27.7000  27.520  27.550   16222
# 2021-03-29 18:00:00+00:00  27.56  27.6500  27.480  27.500   27461
# 2021-03-29 18:45:00+00:00  27.52  27.6600  27.340  27.540   32608
# 2021-03-29 19:30:00+00:00  27.52  27.5700  27.190  27.220  157850
# 2021-03-30 12:45:00+00:00  27.38  27.3800  27.380  27.380    1000
#
#                            trade_count       vwap
# timestamp
# 2021-03-29 13:30:00+00:00          425  28.224072
# 2021-03-29 14:15:00+00:00          279  27.866614
# 2021-03-29 15:00:00+00:00          302  27.697316
# 2021-03-29 15:45:00+00:00          532  27.570272
# 2021-03-29 16:30:00+00:00          348  27.699737
# 2021-03-29 17:15:00+00:00          243  27.586507
# 2021-03-29 18:00:00+00:00          445  27.577994
# 2021-03-29 18:45:00+00:00          461  27.534222
# 2021-03-29 19:30:00+00:00          782  27.262147
# 2021-03-30 12:45:00+00:00           11  27.377660

# %%
# Use the drop function to drop extra columns
df = df.drop(columns=["open", "high", "low", "volume", "trade_count", "vwap"])

# Since this is daily data, we can keep only the date (remove the time) component of the data
df.index = df.index.date

# Display sample data
df.head()
# Out:
#              close
# 2021-03-29  28.010
# 2021-03-29  27.655
# 2021-03-29  27.660
# 2021-03-29  27.470
# 2021-03-29  27.700

# %%
 # Use the `pct_change` function to calculate daily returns of Ethereum
eth_returns = df.pct_change().dropna()
eth_returns.head()
# Out:
#                close
# 2021-03-29 -0.012674
# 2021-03-29  0.000181
# 2021-03-29 -0.006869
# 2021-03-29  0.008373
# 2021-03-29 -0.005415

# %%
# CSV

# %%
# JPEG

# %% [markdown]
# ---

# %% [markdown]
# #### Bitcoin

# %%
# Retrieve BTC stock data
df = api.get_bars("ETH", TimeFrame(45, TimeFrameUnit.Minute), "2021-03-27", "2022-03-27", adjustment='raw').df
df.head(10)
# Out:
#                             open     high     low   close  volume  \
# timestamp
# 2021-03-29 13:30:00+00:00  27.92  28.4600  27.920  28.010   39271
# 2021-03-29 14:15:00+00:00  27.99  28.0688  27.640  27.655   25360
# 2021-03-29 15:00:00+00:00  27.71  27.8200  27.580  27.660   26955
# 2021-03-29 15:45:00+00:00  27.63  27.6700  27.365  27.470   38054
# 2021-03-29 16:30:00+00:00  27.50  27.8400  27.500  27.700   27774
# 2021-03-29 17:15:00+00:00  27.68  27.7000  27.520  27.550   16222
# 2021-03-29 18:00:00+00:00  27.56  27.6500  27.480  27.500   27461
# 2021-03-29 18:45:00+00:00  27.52  27.6600  27.340  27.540   32608
# 2021-03-29 19:30:00+00:00  27.52  27.5700  27.190  27.220  157850
# 2021-03-30 12:45:00+00:00  27.38  27.3800  27.380  27.380    1000
#
#                            trade_count       vwap
# timestamp
# 2021-03-29 13:30:00+00:00          425  28.224072
# 2021-03-29 14:15:00+00:00          279  27.866614
# 2021-03-29 15:00:00+00:00          302  27.697316
# 2021-03-29 15:45:00+00:00          532  27.570272
# 2021-03-29 16:30:00+00:00          348  27.699737
# 2021-03-29 17:15:00+00:00          243  27.586507
# 2021-03-29 18:00:00+00:00          445  27.577994
# 2021-03-29 18:45:00+00:00          461  27.534222
# 2021-03-29 19:30:00+00:00          782  27.262147
# 2021-03-30 12:45:00+00:00           11  27.377660

# %%
# Use the drop function to drop extra columns
df = df.drop(columns=["open", "high", "low", "volume", "trade_count", "vwap"])

# Since this is daily data, we can keep only the date (remove the time) component of the data
df.index = df.index.date

# Display sample data
df.head()
# Out:
#              close
# 2021-03-29  28.010
# 2021-03-29  27.655
# 2021-03-29  27.660
# 2021-03-29  27.470
# 2021-03-29  27.700

# %%
 # Use the `pct_change` function to calculate daily returns of Bitcoin
btc_returns = df.pct_change().dropna()
btc_returns.head()
# Out:
#                close
# 2021-03-29 -0.012674
# 2021-03-29  0.000181
# 2021-03-29 -0.006869
# 2021-03-29  0.008373
# 2021-03-29 -0.005415

# %%
# CSV

# %%
# JPEG

# %%
# Set current date and the date from one month ago using the ISO format
current_date = pd.Timestamp(datetime.now(), tz="America/New_York").isoformat()
past_date = pd.Timestamp(datetime.now()-timedelta(20), tz="America/New_York").isoformat()

# %%
# Use newsapi client to get most relevant 20 headlines per day in the past month
def get_headlines(keyword):
    all_headlines = []
    all_dates = []    
    date = datetime.strptime(current_date[:10], "%Y-%m-%d")
    end_date = datetime.strptime(past_date[:10], "%Y-%m-%d")
    print(f"Fetching news about '{keyword}'")
    print("*" * 30)
    while date > end_date:
        print(f"retrieving news from: {date}")
        articles = newsapi.get_everything(
            q=keyword,
            from_param=str(date)[:10],
            to=str(date)[:10],
            language="en",
            sort_by="relevancy",
            page=1,
        )
        headlines = []
        for i in range(0, len(articles["articles"])):
            headlines.append(articles["articles"][i]["title"])
        all_headlines.append(headlines)
        all_dates.append(date)
        date = date - timedelta(days=1)
    return all_headlines, all_dates

# %%
# Retrieve ethereum news headlines
eth_headlines, dates = get_headlines("ethereum")
# Out:
# Fetching news about 'ethereum'
# ******************************
# retrieving news from: 2022-03-29 00:00:00
# retrieving news from: 2022-03-28 00:00:00
# retrieving news from: 2022-03-27 00:00:00
# retrieving news from: 2022-03-26 00:00:00
# retrieving news from: 2022-03-25 00:00:00
# retrieving news from: 2022-03-24 00:00:00
# retrieving news from: 2022-03-23 00:00:00
# retrieving news from: 2022-03-22 00:00:00
# retrieving news from: 2022-03-21 00:00:00
# retrieving news from: 2022-03-20 00:00:00
# retrieving news from: 2022-03-19 00:00:00
# retrieving news from: 2022-03-18 00:00:00
# retrieving news from: 2022-03-17 00:00:00
# retrieving news from: 2022-03-16 00:00:00
# retrieving news from: 2022-03-15 00:00:00
# retrieving news from: 2022-03-14 00:00:00
# retrieving news from: 2022-03-13 00:00:00
# retrieving news from: 2022-03-12 00:00:00
# retrieving news from: 2022-03-11 00:00:00
# retrieving news from: 2022-03-10 00:00:00

# %%
# View 'ethereum' headlines
eth_headlines
# Out:
# [[],
#  ['Museums Are Cashing In on NFTs',
#   'Why Bitcoin, Ethereum, and Solana All Jumped Today',
#   "You can buy a $20 million California 'MM' vanity license plate",
#   'Top cryptocurrency prices today: Bitcoin, Ethereum, Dogecoin, Shiba Inu gain up to 9%',
#   "In a pitch to cryptocurrency investors, Poilievre says he wants Canada to be 'blockchain capital of the world'",
#   'Ethereum is approaching the ‘merge’ and crypto investors are having major FOMO - Yahoo Finance',
#   'Asteroid Mining Company to Launch NFTs to Fund Resource Extraction In Space',
#   'CryptoCodex: $600 Billion Bitcoin And Crypto Boom Pushes The Price Of Ethereum, BNB, XRP, Solana And Cardano Higher',
#   'Bitcoin price news – live: BTC hits 3-month high as crypto market passes $2 trillion',
#   'Cornerstone Global Management, Inc. acquires Paydrop in historic merger of workplace-focused Cryptocurrency platforms',
#   "First Mover Americas: Ether Hits 2.5-Month High as Google Search Shows Peak Interest in 'Ethereum Merge'",
#   'Ukraine is selling NFTs like war bonds',
#   'GPU prices keep falling, now only 25% above MSRP - WePC - PC Tech & PC Gaming News',
#   'Why XRP, Cardano, and Polkadot Are Surging Higher Today',
#   'Crypto Funds See Largest Inflows Since Mid-December',
#   "Ethereum risks 'double-bust' drop despite ETH price rebounding 30% in two weeks",
#   'NFT Trends: How experimental photography is expanding into the NFT space',
#   'Cryptocurrency News Today: Bitcoin, Ethereum Maintaining Bullish Run',
#   'TA: Ethereum Gains Traction, A Strengthening Case For More Gains',
#   'Outflows Remain The Order Of The Day As Ethereum Crosses $3,300'],
#  ['Bitcoin rises 4.4 percent to $46499 - Reuters',
#   'U.S. Justice Dept. Charges NFT Creators Over "Rug Pull" Scheme',
#   'Big Cryptocurrencies Hold Price Support Levels And Then Rally',
#   'Bitcoin And Crypto Now Braced For A $10 Trillion Earthquake As Ethereum, BNB, XRP, Solana And Cardano Soar',
#   'Why Chiliz Was a Hot Cryptocurrency on Sunday',
#   "Ethereum Founder is Backing Zambia's Bid to be Africa's Tech Hub - Bloomberg",
#   'Ethereum (ETH) Is Trending, with the Bulls Eyeing a Return to $3,500',
#   'Privacy-Protecting Crypto Airdrops with Zero Knowledge Proofs',
#   'Inside the blockchain developers’ mind: What is the ultimate scaling solution?',
#   'Why Bitcoin Has No Competition',
#   'Liverpool projected to earn more than £8.5m from controversial NFT sales',
#   'The 10 Most Important Cryptocurrencies Which Are Popular In EU Countries',
#   'Analyst Michaël van de Poppe Issues Alert for Ethereum (ETH) and Cardano (ADA) Traders – Here Are His New Targets',
#   'Long-Term Ethereum Holders Accumulate $12,000,000,000 in ETH in Matter of Weeks: IntoTheBlock',
#   'Crypto Corner: The Sports Slice',
#   'ETH Due For An Explosive Move As ‘Ethereum Merge’ Google Searches Spike To Unprecedented Highs',
#   'Green, Scalable And More Efficient Ethereum Upgrade: Know About It',
#   'Crypto Carbon: Can Blockchain Networks Fix Carbon Offsets?',
#   'Here’s What’s Ahead for Bitcoin (BTC) and Ethereum (ETH) After Latest Surge, According to Crypto Analyst',
#   'Vitalik Buterin admits ‘fees are a huge problem’ for Ethereum’s usability'],
#  ["I haven't made a profit yet after making, minting, and selling my first NFT, but I have no regrets",
#   'The Quick Guide to Mining Ethereum',
#   'Philosophical Foxes',
#   'Ether outshines Bitcoin for a second week on software-update optimism',
#   'Can Dogecoin Reach $1?',
#   "Inside Jump Trading's Response to a $325 Million Wormhole Heist",
#   'How Can Blockchain Change The Entertainment Industry',
#   'Can Shiba Inu Reach $1 by 2025?',
#   'How to Educate Yourself on DeFi',
#   'Crypto Price Outlook: Analysts Share Catalysts for $BTC, $ETH Breakouts - Business Insider',
#   'NFT Collection Failures Begin to Mount in Flashback to ICO Bust...',
#   '2 Cryptos to Avoid No Matter What',
#   'Top Two Cryptos ? Which Is Better Bitcoin Vs Ethereum?',
#   'Ukraine NFT War Museum Goes Live',
#   'Nike Reports Revenue Growth and Yuga Labs Hits $4 Billion USD Valuation in This Week’s Business and Crypto Roundup',
#   'How to Add a MetaMask Login to Your Laravel Web Application',
#   'Exclusive: Inside The Ukrainian Government’s NFT Sale—And The 3 Young Entrepreneurs Who Helped Create It',
#   'Is Illuvium the first fun crypto RPG video game?',
#   'The Mosque NFT Project to Mint 12,000 Mosques on Ethereum, to Support Over 10 Charities',
#   '\u200b\u200bCriminals are using ‘mixers’ to launder millions in crypto. They’re not illegal yet.'],
#  ['OpenSea vs. Mintable: How the NFT marketplaces compare',
#   'Discover Metaverse Fashion Week, a fashion event that takes place in a virtual universe',
#   'Philosophical Foxes',
#   'Why Bitcoin, Ethereum, and FTX Token Are Rocketing Higher Today',
#   'From the NFL to GameStop, these are all the big companies launching new NFT marketplaces',
#   'This Is What Content Creators and Entrepreneurs Need to Know About Web3',
#   'Rare Pepe NFT Is Not Rare Enough, $500K Lawsuit Alleges',
#   'Ponzi schemes are fraudulent investment schemes that promise high returns with little risk. Here are 5 red flags to look out for',
#   'Museums Are Cashing In on NFTs',
#   'Museums Are Cashing In on NFTs',
#   'NFT Beginners Guide – How Create Your First NFT',
#   'Why Is Dogecoin Switching to Proof of Stake?',
#   'Cryptocurrency Prices Today March 25: Bitcoin rises, Ethereum biggest gainer',
#   'Babel Finance Completes 2-year US$50M BTC/ETH Cross Cryptocurrency Swap',
#   "Top Israeli bank to accept BTC and ETH trading through Paxos' collaboration",
#   'Ethereum price hits $3.2K as anticipation builds ahead of the ‘Merge’',
#   'Ukraine Launches ‘NFT Museum’ to Raise Funds and Remember',
#   'Building a crypto economy that works for everyone',
#   'Google Files Trademark for ‘Non-Fungible Planet’',
#   'Worldâ\x80\x99s first Metaverse Fashion Week is here â\x80\x93 All you need to know'],
#  ['In first for Israeli banking, Leumi to enable crypto trade - Reuters.com',
#   '3 Tips to Take Advantage of the Future Web 3.0 Decentralized Infrastructure',
#   'Can Ethereum Reach $5,000?',
#   'Is Now the Time to Invest in Ethereum?',
#   'Why Ethereum, Solana, and Dogecoin Are Surging Higher Today',
#   'ApeCoin May Be Great Tomorrow, but These 3 Cryptos Are Great Right Now',
#   'How to Transfer From Coinbase to Coinbase Pro',
#   'Ethereum Cofounder Issues Stark NFT Warning Amid Sudden Rally In The Price Of Bitcoin, Cardano, Solana And Dogecoin',
#   '$500 Billion Crypto Boom Suddenly Sends The Price Of Bitcoin, Ethereum, BNB, XRP, Cardano And Solana Soaring',
#   'Someone Is Trying To Sell Their 2023 Acura Integra NFT For 12 Ethereum Or $37,000',
#   'Top cryptocurrency prices today: Cardano, Dogecoin surge up to 13%; Shibu Inu up 5%',
#   'This Is the Percentage of Shiba Inu Holders Actually Making Money',
#   'Why the Price of Cardano Is Rising Today',
#   'Bitcoin Is Far More Than a New Form of Money',
#   'CIBC Tackles Developer Shortage With Hackathons, Skill Training',
#   'What Is Impermanent Loss in Crypto?',
#   'Can Coinbase Adding Cardano Staking Rewards Further Aid Price Pump?',
#   'Terra’s Bitcoin purchase and BlackRock comments back ETH’s surge to $3.1K',
#   'PUBG Developer Teams Up With Solana Labs To Launch Play-To-Earn Crypto Games',
#   'Ethereum price breaks through $3K, but analysts warn that a retest is needed'],
#  ['NFT sales hit $455 million over the past week. These were the 5 best-selling digital collections.',
#   'Issue 01 – Vitalik Buterin, March 2022',
#   "Ethereum Co-founder Vitalik Buterin Warns of Cryptocurrency's Dystopian Potential",
#   'Vitalik Buterin Should Let Ethereum Be Ethereum',
#   '10 Places Where You Can Spend Shiba Inu',
#   'That Bored Apes company got a $4B valuation. Now they’re promising a metaverse',
#   'Crypto Market Crash: 2 Top Cryptocurrencies to Buy Right Now',
#   '3 Cryptos That Could Beat Bitcoin',
#   '3 Cryptocurrencies Poised to Soar in a Market Rebound',
#   'Why Brit Morin And Jamie Schmidt Are BFFs For Crypto-Curious Women',
#   'The State of Bitcoin and Ethereum Mining in 10 Charts',
#   'Vitalik Buterin, Crypto’s Public Intellectual?',
#   'Why Dogecoin Was Up by 4% Today',
#   '2 Top Cryptocurrencies Poised for a Bull Run',
#   'The Metaverse and Crypto',
#   'Zuckerberg Says Instagram to Become an NFT Marketplace',
#   'Bitcoin, Dogecoin, Polkadot, Cardano jump up to 7%; Avalanche drops 5%',
#   'eToro vs. Coinbase: What Should You Use to Buy Crypto?',
#   'Vitalik Buterin, Crypto’s Public Intellectual?',
#   'The State of Bitcoin and Ethereum Mining in 10 Charts'],
#  ['Vitalik Buterin talks about the problems of cryptocurrencies and after being trolled, Tom Brady declares himself his fan',
#   "'The Goal Of Crypto Is Not To Play Games With Million Dollar Pictures Of Monkeys': Ethereum Founder",
#   'Can Ethereum Reach $4,000?',
#   'Decentriq raises $15M to expand its data clean rooms platform',
#   'What Is a Binance Coin (BNB) and What Is It For?',
#   'Betterment vs. Wealthfront: How the automated IRA accounts compare',
#   "Vitalik Buterin Covers First-Ever NFT Issue of 'TIME Magazine'",
#   '‘The casino beckons’: my journey inside the cryptosphere',
#   'Why Bitcoin, Ethereum, and Crypto Stocks Are Soaring Today',
#   'Ethereum 2.0, Make Or Break Is Near',
#   '‘Escape Velocity’—Huge Ethereum Upgrade Could See Its Price Leave Bitcoin, BNB, XRP, Cardano, Solana, Luna And Avalanche In The Dust',
#   '2 Top Cryptocurrencies to Buy and Hold for Decades',
#   'Eckhaus Latta Unveils Inaugural NFT Collection',
#   'Ether Tops $3K For First Time in 2 Weeks',
#   'What Is a POAP NFT?',
#   'There is a greener way to mine crypto',
#   'Ether Tops $3K For First Time in 2 Weeks',
#   'リプロダクティブ・ヘルスのNoula Health、140万米ドルをプレシード調達——少数派のラテン系女性起業家によるスタートアップ',
#   'Codespaces moves into public beta, the virtual real estate worth millions, and how microservices and CI/CD can hurt productivity (Ep. 425)',
#   'Billionaires Elon Musk And Michael Saylor: Dump The Dollar And Buy Physical Things'],
#  ['I Spent 80 Minutes Inside Vitalik Buterin’s Brain. Here’s What I Learned',
#   'Crypto sector posts outflows for 2nd straight week -CoinShares - Reuters',
#   'Mintable review: Low creator fees, NFT trading, and more',
#   'GTC 2022: GPU topics go beyond tech prowess and applications - The Madison Leader Gazette',
#   'GTC 2020: GPU topics go beyond tech prowess and applications',
#   'Why Ethereum and ApeCoin Were Sinking on Sunday',
#   "Ethereum cofounder Vitalik Buterin warns about Bored Ape NFTs and massive displays of wealth in the crypto space: 'It becomes a different kind of gambling'",
#   '2 Cryptos That Can Double Your Money',
#   'Ethereum ‘Merge’ Edging Closer as Kiln Testing Continues',
#   'The Future of Ethereum Sucks, and I Feel Fine',
#   'Microsoft Investigating Claim of Breach by Extortion Gang',
#   'Cannot offset losses from one crypto against gains from another, clarifies govt',
#   'What Layer 1 Protocols Must Learn From the Telecom Crash',
#   'Billionaires Elon Musk And Michel Saylor: Dump The Dollar And Buy Physical Things',
#   "Ether bulls eye resistance at $3K as the network prepares to undergo 'The Merge'",
#   'Sylvester Stallone Gets In The Ring On NFTs',
#   'RTX 3080 Prices Plummet Overnight (in Australia)',
#   'Why the Price of ApeCoin Is Falling Today',
#   'CryptoCodex: Serious Bitcoin And Crypto Hack Warning As Apecoin Price Plummets',
#   'Crypto mining costs: No I-T deduction to be allowed, says govt'],
#  ['The 5 Best High-Return Investments',
#   'Is Shiba Inu Winning as a Payment Method?',
#   'Crypto Price Prediction: Huge Bitcoin Forecast Revealed As Ethereum, BNB, XRP, Solana, Cardano, Luna And Avalanche Swing',
#   'The Top 6 Graphical Linux Browsers to Install With WSLg',
#   'Curious About Ether? How to Trade It on Margex',
#   'NFTs Are Terrible: 6 Reasons Why You Should Avoid Them',
#   'Business briefs for 3-20-22 | Local News | wyomingnews.com - Wyoming Tribune',
#   'Bitgert Growing Rapidly With its Startup Studio Program - Analytics Insight',
#   "Tax Talk: Virtual or cryptocurrency is treated as 'property' by the IRS",
#   'Every Bitcoin helps: Crypto-fueled relief aid for Ukraine',
#   'Bitcoin Breaks Past The $40,000 Barrier Again – Can It Sustain The Momentum?',
#   'Ethereum Turns Bullish as Exchange Outflows Reach 190,000 ETH',
#   'Ethereum Merge Inches Closer After the Final Launch Of Kiln Testnet',
#   'Metametaverse Raises $2 Million To Build An Interoperable Metaverse',
#   'First Mover Asia: Singapore-Based Gaming Company Razer Struggles to Pivot; Bitcoin Declines After a Positive Week',
#   'Revisiting Bitcoin’s Energy ‘Problem’ in the Face of ESG Investment Mandates',
#   "Ethereum's Vitalik Buterin Comes with New Sharding Proposal: What is EIP-4844?",
#   'Shiba Inu Price Spikes 7%, Outperforming Other Top Coins',
#   'Ethereum Whales Pick Up The Pace While ETH Nears $3000 For The First Time In Weeks',
#   'Tom Brady Wants to Meet Vitalik Buterin'],
#  ["Web3 Could See Its Own Dot-Com Boom. Here's How To Survive The Bust.",
#   'Why ApeCoin Is Climbing Again Today',
#   '2 Metaverse Investments to Avoid Like the Plague',
#   'Can Shiba Inu Reach $1?',
#   'Ethereum balance on crypto exchanges falls to lowest levels since 2018',
#   'BTC, ETH, AVAX and SOL Price Analysis for March 19 - U.Today',
#   'Bitcoin to the rescue: Cryptocurrencies’ role in Ukraine',
#   'Weekend Recovery Sees Ether Outperform Bitcoin as ETH Gains 5%',
#   'NFT airdrops are exciting but do your own research before participating',
#   'Ethereum Sees Biggest Exchange Withdrawals This Year – A Bump In ETH Price In The Offing?',
#   'Bitcoin And Crypto Price Crash Triggers Serious Coinbase Warning',
#   'The Nightly Mint: Daily NFT Recap',
#   'Avalanche (AVAX) Targets $100 as Layer-1 Protocols Shine',
#   "I paid $103 for a cartoon pig NFT on the largest online marketplace for digital tokens. Now I don't know what to do with it.",
#   'Who Pays For Ethereum’s Complexity? A Lead Developer Speaks Up',
#   'Ethereum Flashes Ultra-Bullish Signal — Nearly 200,000 ETH Withdrawn From Exchanges In A Day',
#   'Wall Street Breakfast: What Moved Markets',
#   'Is Ethereum About To Erupt? Analytics Firm Says ETH Is Flashing Bullish Signal',
#   'He May Be a Financial Titan Like No Other',
#   'The Nightly Mint: Daily NFT Recap'],
#  ['TIME Releases First-Ever Full Magazine Issue as an NFT on the Blockchain Featuring a Cover Story on Ethereum Co-Founder Vitalik Buterin',
#   "Kingship, the band based on NFT's, has a new virtual manager and Universal Music paid $ 360 thousand dollars for her",
#   'Is Waves Crypto a Buy?',
#   'Why Ethereum Did Better Than Most Stocks on Friday',
#   'Profile of Vitalik Buterin, who says he has decided to become "more risk-taking and less neutral" in order to more actively shape the future of Ethereum (Andrew R. Chow/TIME)',
#   'HYPETALKS Will Explore Women Shaping the Future of Web3',
#   'Why This Crypto Is Different From All the Others',
#   'This Under-the-Radar Cryptocurrency Could Be the Next Shiba Inu',
#   'Top cryptocurrency prices today: Avalanche jumps 5%; Solana, Polkadot and Bitcoin drop up to 3%',
#   'Crypto is an Unproductive Bubble',
#   'What is ENS and How to Get a .ETH Domain',
#   'Why Coinbase and Solana Were Up on Friday',
#   'This Senate Candidate Wants to Make Bitcoin Legal Tender With No Taxes',
#   'Why the Price of ApeCoin Is Skyrocketing Today',
#   'The Man Behind Ethereum Is Worried About Crypto’s Future',
#   'Crypto Investors File a Class Action Against Crypto Giant Coinbase',
#   'Bitcoin spikes to $41.7K highs as Ethereum nears $3K reclaim',
#   'Altcoin Roundup: Three layer-1 protocols see inflows amid choppy, volatile market conditions',
#   'Market Wrap: Ether Outperforms, Bitcoin Rises Above $42K',
#   'Just How Green Is Green Crypto?'],
#  ['ConsenSys bags $450M in megaround as investors flock to back blockchain',
#   "NFT's Run-Up Rekindles Chatter About Manipulation Ahead of Deal",
#   'If you’re a Russian YouTuber, how do you get paid now?',
#   'MetaMetaverse aims to make the metaverse interoperable',
#   'Ethereum L2 scaling startup Optimism raises a $150M Series B led by Andreessen Horowitz and Paradigm at a $1.65B valuation (Lucas Matney/TechCrunch)',
#   "Bored Ape Yacht Club's $APE token hit a peak of $39.40 per token during its airdrop, but later sank as low as $7.50 (Andrew Hayward/Decrypt)",
#   'Why Bitcoin, Ethereum, and Dogecoin Are Continuing to Rise Today',
#   'No Contest: My Top Crypto to Buy Now',
#   '1 Cryptocurrency That Even This Skeptic Is Buying',
#   'HIVE Blockchain: The Ethereum Gambit',
#   'What are the environmental impacts of cryptocurrencies?',
#   'The Fight Against Inflation Has Begun and Bitcoin is Ready to Help',
#   "Everybody Is Mad About 'ApeCoin'",
#   'International Cryptocurrency Exchange KuCoin Paid $100,000 Bonuses To Employees And Salaries In Bitcoin, Ethereum And Other Cryptocurrencies',
#   '3 Rising Cryptos That Are Up More Than 10% Over the Past Week',
#   'A16z, Paradigm Lead $150M Round for Ethereum Scaling Solution Optimism at $1.65B Valuation',
#   'Senator Elizabeth Warren Introduces A Game-Changing Crypto Bill As The Price Of Bitcoin, Ethereum, BNB, XRP, Luna, Cardano, Solana And Avalanche Surge',
#   'Ethereum moves closer to proof-of-stake after Kiln',
#   'GPU Modder Lowers GDDR6X Temps by 46C with Copper Shims',
#   'A16z, Paradigm Lead $150M Round for Ethereum Scaling Solution Optimism at $1.65B Valuation'],
#  ['NFT sales fell to $63 million over the past week. These were the 5 best-selling digital collections.',
#   'OpenSea vs. FTX.US: How the NFT and crypto marketplaces compare',
#   'Big mistake! Collector sells the NFT of a rock worth $1 million for a penny',
#   'ASIC mining: Computers built specifically for mining cryptocurrency',
#   'Why Bitcoin, Ethereum, and Dogecoin Are Gaining Today',
#   "Interview with Automattic CEO Matt Mullenweg on the company's growth, the future of open-source WordPress, Tumblr moderation, Web3, Bitcoin, Ethereum, and more (Nilay Patel/The Verge)",
#   'N.W.A.’s ‘Straight Outta Compton’ Platinum Album Plaque Is Up for Auction as an NFT',
#   "The 1 Cryptocurrency I'm Buying in March",
#   'Ethereum Merge Takes Place on Kiln Testnet',
#   'The Best Global Crypto Exchanges',
#   'Latest Ethereum price and analysis (ETH to USD)',
#   'This Crypto Stock Is a True Trailblazer: Find Out Why',
#   'How cryptocurrency is being used to funnel money to Ukraine',
#   'What Is A Decentralized App (DApp)?',
#   'Anatomy of a Crypto Bear Market',
#   '3 reasons why Ethereum price can still retest $3K this month',
#   '‘Undeniable’ growth in financial utility of blockchain: Adam Dell',
#   'News Direct Becomes First Newswire to Accept Cryptocurrency for Payments',
#   'The World’s First Yacht NFT Just Sold for $12 Million—With an IRL 110-Footer to Follow',
#   'DeFi Platform Aave Lauches V3 With Cross-Chain Swaps Front and Center'],
#  ['Cryptocurrency payments are accepted the most by the travel industry, adoption study shows',
#   'ConsenSys valuation more than doubles to over $7 bln after latest funding - Reuters.com',
#   'Guess the Startup',
#   'ConsenSys, which develops and invests in Ethereum projects, announces a $450M Series D led by ParaFi Capital at a $7B valuation and says MetaMask has 30M+ MAUs (Ian Allison/CoinDesk)',
#   "Billionaire Mark Cuban takes a swipe at Elon Musk's question about what inflation could look like in the coming years",
#   'It happened to me: I accidentally attended a crypto bro dinner',
#   "What's Driving Ethereum, Dogecoin, and THORChain Higher Today?",
#   "Mila Kunis Launches New Solana-based NFT Animated Series, 'The Gimmicks'",
#   'Ethereum Software Company ConsenSys Doubles Valuation To $7 Billion In Four Months Amid Market Turbulence',
#   'Is Shiba Inu Ready for a Bull Run?',
#   'Apple Cofounder Reveals Huge Bitcoin Price Prediction—And A Stark Crypto Warning As Ethereum, BNB, XRP, Luna, Cardano, Solana And Avalanche Ricochet',
#   'Dr Disrespect-backed game developer selling early access NFTs',
#   '$450M Raise Values Ethereum Builder ConsenSys at $7B as MetaMask Tops 30M Users',
#   'Bitcoin price news – live: Crypto market ‘stuck’ as trading volume drops to monthly low',
#   'Echelon Malware Targets Crypto Wallets: Here’s How You Can Protect Yourself',
#   'ExpressVPN vs. Surfshark: Which is the better VPN in 2022?',
#   'Brazilian Asset Manager Hashdex to Launch Web 3 ETF on Local Stock Exchange',
#   'MakeMyTrip launches limited edition NFTs to commemorate Indian tourism',
#   'How to Buy Cryptocurrency',
#   'BITMANU: Investment Opportunity during War and Inflation'],
#  ["Elon Musk Offers Advice on Inflation, Says He Won't Be Selling Crypto: 'It Is Generally Better to Own Physical Things'",
#   'Foundation review: Create, sell, and collect NFTs',
#   "Bored Ape creator's purchase of CryptoPunks means it now owns the two of the top-selling NFT projects",
#   "Elon Musk advises owning 'physical things' like homes and stocks when inflation is high – but says he won't sell his bitcoin, ether, and dogecoin",
#   "Elon Musk advises owning 'physical things' like homes and stocks when inflation is high – but says he won't sell his bitcoin, ether, and dogecoin",
#   'The Benefits Of Venture Capital In Web3',
#   'Blockchain in Clinical Trials: Can it Improve Transparency?',
#   'Why the "Russian Ethereum" Is Trouncing Shiba Inu Right Now',
#   'Why crypto is unlikely to be useful for sanctions-dodgers',
#   'MADSTEEZ Debuts Hand-Drawn WEENimals NFT Collection',
#   'AMBUSH® Launches First Metaverse Space, SILVER FCTRY',
#   '‘I Won’t Sell’—Tesla Billionaire Elon Musk Issues Inflation Advice As The Price Of His Bitcoin, Ethereum And Dogecoin Plummet',
#   'Cryptocurrencies in 2022: An Interview with Tim Seymour and Meltem Demirors',
#   'Robo Money: Best Robo Advisor Apps to Help You Automate Investments',
#   'Cryptocurrency prices mixed; Bitcoin trading at $39000 - Fox Business',
#   'Top cryptocurrency prices today: Avalanche, Bitcoin, Ethereum, Shiba Inu drop up to 6%',
#   'Ukraine to launch an NFT collection depicting Russian-Ukrainian war',
#   'How to Mine Cardano (ADA) On Your Computer',
#   'Ethereum Staking Protocol Swell Raises $3.75M as Locked ETH Tops $26B',
#   'EU Parliament committee decides not to ban proof-of-work cryptos'],
#  ['How People Actually Make Money From Cryptocurrencies',
#   "Sam Bankman-Fried says Biden's crypto order won't move the needle, but Cameron WInklevoss calls it a watershed. Here are the 8 top reaction quotes from crypto players.",
#   'ReNFT Lets Token Holders Rent And Lease Their Digital Assets',
#   'Sanctions-dodgers hoping to use crypto to evade detection are likely to be disappointed',
#   'Why crypto is unlikely to be useful for sanctions-dodgers',
#   'Manifold.xyz Helps Users Like Jay-Z And Steve Aoki Mint NFTs',
#   'Are NFTs profitable? One Saratoga Springs business is finding out - Times Union',
#   "If You Invested $100 In Bitcoin, Ethereum And Dogecoin When Joe Biden Took Office, Here's How Much You'd - Benzinga",
#   'What is Solana (SOL) Pay, and how does it work?',
#   'Explained: The legal considerations of blockchain gaming in India',
#   'Solana (SOL), Cardano (ADA), Avalanche (AVAX) and Bitgert (BRISE) - Which Has the Fastest Blockchain? - Analytics Insight',
#   "Bitcoin-Banning Measure Seen Too Close to Call in Tomorrow's EU Parliament Vote",
#   'Musician Dillon Francis on Ethereum vs Solana for NFTs',
#   '23-year-old Australian buys $314k property via planned crypto investments',
#   'Crypto Week at a Glance: World moves towards crypto regulations amid volatility',
#   'Crypto Tax Software: Manage Bitcoin and Other Digital Currencies - CNET',
#   'Crypto industry warns of ‘existential threat’ from draft EU regulation',
#   'Fake Valorant cheats on YouTube infect you with RedLine stealer',
#   'What Does The Future Hold For Bitcoin Mining?',
#   'Here’s how DAOs are making digital land more accessible to Metaverse denizens'],
#  ['NFTs Don’t Work the Way You Might Think They Do',
#   '2 Top Cryptocurrencies To Buy and Hold Forever',
#   'What Is Shiba Inu & Is It Like Dogecoin?',
#   'The Price Of Ripple’s XRP Is Suddenly Surging As Bitcoin, Ethereum, BNB, Solana, Cardano, Terra’s Luna And Avalanche Are Flatflining',
#   'Crypto Wallet fob concept gives digital currency a physical form',
#   'Is Fantom the Next Shiba Inu?',
#   'Can Shiba Inu Reach $0.0001 in 2022?',
#   'Bored Ape Yacht Club creator acquires CryptoPunks and Meebits NFT collection',
#   'Warner Bros. is launching DC Comics trading cards with redeemable NFTs',
#   'Terra (LUNA) Surpasses Ethereum Becoming Second Most Staked Asset',
#   "Spotify Who? Musician's Earnings Go From $300 to $60,000 in Web3",
#   'Immutable X (IMX) gains 50% following the close of a $200M fundraising round',
#   'Shiba Inu To Reach $0.001 After Bitgert Plans To Launch Wrapped Shiba Inu Token? - Analytics Insight',
#   'Limiting Proof-of-Work Crypto Back on the Table as EU Parliament Prepares Virtual Currencies Vote',
#   'Crypto Biz: Goldman Sachs tip-toes into ETH, Mar. 4-10',
#   'Why do people say NFTs are bad? Let’s dive in.',
#   'The Nightly Mint: Daily NFT Recap',
#   'How Crypto Could Become The Dominant Source To Store And Move Value By 2030',
#   'Kadena price soars by 40% after new protocol launches and a major exchange listing',
#   'The First Crypto War May Lead to Lasting Peace'],
#  ["Kevin O'Leary says 20% of his portfolio is in crypto and blockchain with investments in 32 places: 'You don't know who's going to win'",
#   'One year after Beeple sale, NFTs have become mainstream',
#   "The US dollar could go digital. Here's what you need to know",
#   'Ethereum Whales Love Shiba Inu -- Should You?',
#   'Gate.io review: Trade more than 1,000 cryptocurrencies with as little as $10',
#   'The Most Popular and Best Selling NFT Collections This Week',
#   'Cryptocurrency Fuels Explosive Growth of Crime',
#   'How To Navigate Solana NFTs',
#   'Looking for the Next Shiba Inu? 2 Top Cryptocurrencies to Buy and Hold',
#   '2 Top Cryptocurrencies That Are Screaming Buys in March',
#   '3 Top Cryptos That Are Now Down Big Over the Past Year',
#   'How To Recover Bitcoin Wallet',
#   '10 Easy Steps to Connect Metamask to Binance Smart Chain',
#   'Evmos Looks to Get Back on Track After Failed Launch',
#   'Is Cardano the Next Visa of Crypto?',
#   'Why NFTs Are the Next Big Thing (If You’re A Complete Moron)',
#   'Evmos Looks to Get Back on Track After Failed Launch',
#   'Did the London Upgrade Fix Ethereum’s Gas Fee Problem?',
#   'Safeguarding Our Privacy in an Age of Transparency',
#   'EdenLoop (ELT) Announces Uniswap Listing'],
#  ['US stock futures dip as investors focus on diplomatic talks between Russia and Ukraine ahead of key inflation data',
#   'Nonfungible.com: NFT game sales hit $5.17B in 2021',
#   'Why Bitcoin, Ethereum, and Dogecoin Dropped Today',
#   'TIME Studios to create Children’s Series Based on the littles NFT',
#   'Looking for the Next Ethereum? 2 Cryptocurrencies to Buy Now',
#   "Should You Buy Ethereum While It's Still Below $3,000?",
#   "We Filmed at a Bitcoin Conference in 2013. Here's What Those People Are Doing Now",
#   'Top crypto prices today: Bitcoin, Terra, Ethereum zoom up to 6%; Shiba Inu flat',
#   'Vitalik Buterin Asks Court For Leniency in Upcoming Sentencing of Virgil Griffith',
#   "Shiba Inu vs. Dogecoin: Which Pupcoin's More Bite Than Bark?",
#   'What is blockchain technology and how does it work?',
#   'Biden Orders Report on Climate Risk of Cryptocurrencies',
#   "Can Shiba Inu Repeat Last Year's Gain?",
#   'Color Innovator Pantone To Give Away Limited NFTs In Free Raffle',
#   'What Happened to the Dream of Private Cryptocurrency?',
#   'Vitalik Buterin Asks Court For Leniency in Upcoming Sentencing of Virgil Griffith',
#   'Famed NFT Bored Ape Yacht Club Donates $1 Million To Help Ukraine',
#   'My Conversation with the excellent Sam Bankman-Fried',
#   'Win Crypto, up to $500 in Bitcoin, NFTs and Ethereum with Zipmex and Penrith Panthers',
#   'Now accepting donations in 23 currencies around the world!']]

# %%
# Retrieve bitcoin news headlines
btc_headlines, _ = get_headlines("bitcoin")
# Out:
# Fetching news about 'bitcoin'
# ******************************
# retrieving news from: 2022-03-29 00:00:00
# retrieving news from: 2022-03-28 00:00:00
# retrieving news from: 2022-03-27 00:00:00
# retrieving news from: 2022-03-26 00:00:00
# retrieving news from: 2022-03-25 00:00:00
# retrieving news from: 2022-03-24 00:00:00
# retrieving news from: 2022-03-23 00:00:00
# retrieving news from: 2022-03-22 00:00:00
# retrieving news from: 2022-03-21 00:00:00
# retrieving news from: 2022-03-20 00:00:00
# retrieving news from: 2022-03-19 00:00:00
# retrieving news from: 2022-03-18 00:00:00
# retrieving news from: 2022-03-17 00:00:00
# retrieving news from: 2022-03-16 00:00:00
# retrieving news from: 2022-03-15 00:00:00
# retrieving news from: 2022-03-14 00:00:00
# retrieving news from: 2022-03-13 00:00:00
# retrieving news from: 2022-03-12 00:00:00
# retrieving news from: 2022-03-11 00:00:00
# retrieving news from: 2022-03-10 00:00:00

# %%
# View 'bitcoin' headlines
btc_headlines
# Out:
# [['The Challenges With Fully Syncing Old Versions Of Bitcoin Core',
#   'GST evasion: Rs 95 cr recovered from 11 crypto bourses',
#   'Cathie Wood’s ARK Invest Buys for 3/28',
#   'Cathie Wood’s ARK Invest Sells for 3/28'],
#  ['Yen back under pressure as BOJ steps in bitcoin takes a leap - Reuters',
#   'A new bill would launch a large-scale test of digital dollars',
#   "Brett Arends's ROI: Russia just made a case for owning gold—and nobody noticed",
#   'Bitcoin erases 2022’s losses as bulls eye $50,000',
#   'Why Bitcoin Mining Stocks Jumped on Monday',
#   'Top cryptocurrency prices today: Bitcoin, Ethereum, Dogecoin, Shiba Inu gain up to 9%',
#   'Why Bitfarms Stock Rallied by 10% Today',
#   'Why Bitcoin, Ethereum, and Solana All Jumped Today',
#   'Why Block Stock Was Rallying More Than 4% Higher Today',
#   'Triton malware still a threat to energy sector, FBI warns',
#   'Bitcoin’s stealth rally erases its losses for the year',
#   'Bitcoin After 2140: Differing Views On The Future Of The Future Of Money',
#   'Bitcoin Surges Past $47,000, And Institutional Investors May Not Be Far Behind',
#   'Biden Administration Plans New Limits on Stock Buybacks',
#   "In a pitch to cryptocurrency investors, Poilievre says he wants Canada to be 'blockchain capital of the world'",
#   'Why Shares of Coinbase Are Rising',
#   'Bitcoin Meetup In A Country Known For Its Self-Custodial Culture',
#   'Yen back under pressure as BOJ steps in Bitcoin takes a leap',
#   "Recession Signals Light Up as Section of US 'Yield Curve' Inverts",
#   'CryptoCodex: $600 Billion Bitcoin And Crypto Boom Pushes The Price Of Ethereum, BNB, XRP, Solana And Cardano Higher'],
#  ['Bitcoin rises 4.4 percent to $46499 - Reuters',
#   'War Impacts On Storing Assets Like Crypto, Gold and More',
#   'SailGP partners with NEAR to create a DAO for crypto-owned teams',
#   'Why Bitcoin Sailed Higher on Sunday',
#   'Crypto Bonds Are Exciting, But Due Diligence Is Always Required',
#   'Bitcoin And Crypto Now Braced For A $10 Trillion Earthquake As Ethereum, BNB, XRP, Solana And Cardano Soar',
#   'Big Cryptocurrencies Hold Price Support Levels And Then Rally',
#   'With Russia War On The Brain, Could Congress Levy A Kill Shot To DeFi?',
#   'El Salvador Bets on Bitcoin Mania',
#   'Why Bitcoin Has No Competition',
#   'Bitcoin Springs Past $46K to Hit 3-Month High',
#   'Exploring The Correlation Between Bitcoin Price And Google Search Trends',
#   'What’s Up With S2F? — A Look At The Popular Bitcoin Model',
#   'Just as Hal Finney Predicted, Bitcoin Is Being Purchased to Act as a Reserve Currency',
#   "First Mover Asia: Crypto Concerns Weigh on Taiwan PC Component Makers' Stocks; Bitcoin Springs to 3-Month High",
#   'Just as Hal Finney Predicted, Bitcoin Is Being Purchased to Act as a Reserve Currency',
#   'Bitcoin Springs Past $46K to Hit 3-Month High',
#   "First Mover Asia: Crypto Concerns Weigh on Taiwan PC Component Makers' Stocks; Bitcoin Springs to 3-Month High",
#   'Macquarie, BCI Buy National Grid Gas Unit Stake For $5.5 Billion',
#   'Bitcoin Is Struggling Below $45,000 But There Are Signs it Could Break Out'],
#  ["I haven't made a profit yet after making, minting, and selling my first NFT, but I have no regrets",
#   'Ether outshines Bitcoin for a second week on software-update optimism',
#   'Should you start accepting salary in Bitcoin?',
#   'Bitcoin Game Theory Intensifies: Russia Accepts Bitcoin For Exports',
#   'The Quick Guide to Mining Ethereum',
#   'Bitcoin Is On FIRE',
#   'Crypto Price Outlook: Analysts Share Catalysts for $BTC, $ETH Breakouts - Business Insider',
#   'Is Miner Concentration Once Again Jeopardizing Bitcoin? Not Exactly',
#   'Great American Mining Is Solving Our Global Energy Problems With Bitcoin',
#   'How Can Blockchain Change The Entertainment Industry',
#   'Can Dogecoin Reach $1?',
#   'Crypto aid for Ukraine: innovation or just a sideshow?',
#   "Thailand Outlawing Crypto Payments. This Week's Top Bitcoin and Crypto News - CNET",
#   'How to Educate Yourself on DeFi',
#   'Is Miner Concentration Once Again Jeopardizing Bitcoin? Not Exactly',
#   'Are Russia’s Elite Really Using Cryptocurrency to Evade Sanctions?',
#   'Why Did John McAfee Stop Paying Taxes? ‘I’d Just Had Enough’',
#   'Can Shiba Inu Reach $1 by 2025?',
#   "Biden's proposal for a new digital currency is an attack on liberty - Fox Business",
#   'Can Crypto Miners Make the World Greener?'],
#  ['Crypto Goes to War in Ukraine',
#   'Ponzi schemes are fraudulent investment schemes that promise high returns with little risk. Here are 5 red flags to look out for',
#   "Ukraine launches NFT 'Museum of War' in crypto crowdfunding push - Reuters",
#   '‘Free Anna Delvey’: Anna Sorokin show features art ‘inspired’ by fake heiress',
#   'Crypto: Bitcoin rallies after Russia hints at using crypto with $50,000 seen possible on short covering',
#   'Russia considers accepting Bitcoin for oil and gas',
#   'What Is Bitcoin Cash (BCH) and How Can You Spend It?',
#   'Exxon Considering Expanding Bitcoin Mining Pilot to 4 Countries: Report',
#   'UK teens arrested in connection with Lapsus$ Microsoft hacks - PCGamesN',
#   'Why Is Dogecoin Switching to Proof of Stake?',
#   'The Wall Street Journal: Financial advisers aren’t sold on crypto',
#   'Why Bitcoin, Ethereum, and FTX Token Are Rocketing Higher Today',
#   'Why Riot Blockchain, SOS, and Canaan Had One Heck of a Good Week',
#   "The Real Extraterrestrial Artifact In Tut's Tomb",
#   'Will Tether Migrate To The Bitcoin Blockchain With Advances In The Lightning Network?',
#   "Bitcoin Tops $44K Amid Rumors of Terra's LFG Accumulating BTC",
#   'How Northern Italian Hydropower Producers Became Bitcoin Miners',
#   'Bitcoin City: El Salvador’s Dreams for Utopia on Hold',
#   'Market Wrap: Bitcoin Outperforms as Crypto Bulls Take a Breather',
#   'Former Party Organizer Indicted for Laundering $2.7M in Bitcoin and Cash'],
#  ['Ex-Party Producer Charged in $2.7 Million Bitcoin-Laundering Scheme',
#   'Everyone Has Crypto FOMO, but Does It Belong in Your Portfolio?',
#   'Young Ukrainian Escapes War With USB Stick Holding 40% of His Life Savings In Crypto',
#   'In first for Israeli banking, Leumi to enable crypto trade - Reuters.com',
#   'Crypto offshoot DeFi throws up new risks for investors, global regulators say - Reuters.com',
#   "Superstar plays superstar in 'The Fame Game'",
#   'Drake Donates $1 Million USD in Bitcoin to the LeBron James Family Foundation',
#   'Can Bitcoin Save You From Inflation?',
#   'Exxon Weighs Taking Gas-to-Bitcoin Pilot to Four Countries',
#   'Crypto: Russia-Ukraine war could accelerate use of digital currencies, Blackrock’s Larry Fink says',
#   'Goldman Extends Its Crypto Tentacles in Answer to Wall Street FOMO',
#   'Why Bitcoin, Coinbase, and Silvergate Capital Are Rising Today',
#   "This 'Decentralized Finance' Millionaire Moved to Puerto Rico to Avoid Taxes",
#   'HubSpot Data Breach Ripples Through Crytocurrency Industry',
#   'Biden Arrives in Brussels & the Okta Breach Details (Podcast)',
#   '$500 Billion Crypto Boom Suddenly Sends The Price Of Bitcoin, Ethereum, BNB, XRP, Cardano And Solana Soaring',
#   'Everyone has crypto FOMO, but does it belong in your portfolio?',
#   'Ethereum Cofounder Issues Stark NFT Warning Amid Sudden Rally In The Price Of Bitcoin, Cardano, Solana And Dogecoin',
#   '7 Wild Bitcoin Mining Rigs',
#   'Valkyrie’s Head Of Research Lists Top Two Lessons Learned After Almost A Decade In Crypto'],
#  ['El Salvador turns to Binance for help on bitcoin adoption - Reuters.com',
#   'Improved risk sentiment and high commodity prices help Aussie, hurt yen - Reuters.com',
#   'Web3 Is Centralized (and Inefficient)',
#   'El Salvador postpones its $1B bitcoin-backed bond, planned for March 15-20, citing unfavorable market conditions; BTC is down significantly from a November peak (Nelson Renteria/Reuters)',
#   'Digital Currencies Will Require New Rules to Protect Consumers, Fed Chair Says',
#   'Waitroom launches livestreaming platform for real-time communication',
#   "Don't Call It A Comeback: The Unlikely Rise Of Home Bitcoin Mining",
#   'Bitcoiner eyes New Hampshire GOP Senate primary',
#   '3 Cryptos That Could Beat Bitcoin',
#   'Why Dogecoin Was Up by 4% Today',
#   'Learn about iGaming Technology Trends for 2022',
#   'Crypto Market Crash: 2 Top Cryptocurrencies to Buy Right Now',
#   '10 Places Where You Can Spend Shiba Inu',
#   'eToro vs. Coinbase: What Should You Use to Buy Crypto?',
#   'A Book Review Of “Bitcoin Is Venice”',
#   'Trammel Venture Partners Launches Bitcoin-Focused Institutional Investor Fund',
#   'DeadBolt Ransomware Resurfaces to Hit QNAP Again',
#   'Bitcoin, Dogecoin, Polkadot, Cardano jump up to 7%; Avalanche drops 5%',
#   "Bitcoin Is Overtaking The World's Previously Most Popular Brand: The US Dollar",
#   'The State of Bitcoin and Ethereum Mining in 10 Charts'],
#  ["Cryptoverse: Remember when bitcoin was 'anonymous'? - Reuters",
#   'El Salvador postpones bitcoin bond issue, expects better conditions - Reuters.com',
#   'Bitcoin climbs to highest in almost three weeks - Reuters.com',
#   'El Salvador postpones bitcoin bond issue, expects better conditions - Reuters.com',
#   'U.S. fintech Acorns to give users exposure to bitcoin via ProShares ETF - Reuters.com',
#   'Using coal waste to power crypto in Pennsylvania - Reuters',
#   'Russians are using crypto to evade sanctions — but it’s not just the elite',
#   "Britain's advertising watchdog clamps down on crypto firms - Reuters.com",
#   '"Bored Ape" NFT-startup Yuga Labs valued at $4 bln after funding - Reuters',
#   '‘The casino beckons’: my journey inside the cryptosphere',
#   'Vitalik Buterin talks about the problems of cryptocurrencies and after being trolled, Tom Brady declares himself his fan',
#   'How to Sell Cryptocurrency',
#   'Betterment vs. Wealthfront: How the automated IRA accounts compare',
#   "Goldman Shows 'Institutions Are Here' For Crypto",
#   "Crypto's Darwinism Makes VCs King of the Apes",
#   "I considered replacing my credit card with PointsCard, a rewards-earning debit card — and it's a surprisingly good option",
#   "Vitalik Buterin Covers First-Ever NFT Issue of 'TIME Magazine'",
#   'Why Bitcoin, Ethereum, and Crypto Stocks Are Soaring Today',
#   'Why Mawson Infrastructure Stock Popped 10%',
#   "Cryptoverse: Remember when bitcoin was 'anonymous'?"],
#  ['U.S. company devises method to use coal waste to power crypto - Reuters',
#   'Crypto sector posts outflows for 2nd straight week -CoinShares - Reuters',
#   'Goldman Sachs trade with Galaxy Digital marks first over-the-counter crypto transaction by a major US bank, report says',
#   'HubSpot Hack Leads To Data Breaches at BlockFi, Swan Bitcoin, NYDIG and Circle',
#   'Goldman Sachs Makes History With First-Ever OTC Crypto Trade',
#   'Global regulators monitor crypto use in Ukraine war - Reuters',
#   'US stocks edge lower as oil prices rebound amid ongoing Russia-Ukraine conflict',
#   'Euroclear joins bank-backed blockchain payment system - Reuters.com',
#   'US stocks fall after Fed chair Jerome Powell signals openness to more aggressive rate hikes to fight inflation',
#   'Crypto: Ray Dalio said he held some bitcoin. Now Bridgewater is reportedly preparing to back a crypto fund for the first time',
#   'Yen kicks off another week under pressure, with central bank policy in focus - Reuters.com',
#   'GTC 2022: GPU topics go beyond tech prowess and applications - The Madison Leader Gazette',
#   'GTC 2020: GPU topics go beyond tech prowess and applications',
#   'Tom Brady Implores Crypto Trader FTX To Help Fan Who Spent $518K USD on Pre-Retirement Touchdown Ball',
#   "Here's Why Bitcoin Is The Least Popular Inflation Hedge",
#   'What Do Businesses Do If Sanctions Are Lifted?',
#   '2 Cryptos That Can Double Your Money',
#   '‘National Strategic Military Implications’—MIT Researcher Issues Surprise U.S. Bitcoin Warning Amid Crypto Price Crash',
#   'Personal Finance Daily: Why one analyst believes home sales may drop 25% by the end of summer and credit reports will soon stop counting most medical debt',
#   'Yes, You Can Be Fired for Being Fat (Podcast)'],
#  ['The 5 Best High-Return Investments',
#   'Keeping It Simple',
#   'Margins of Up to 90% Give Energy Firms That Mine Bitcoin an Edge',
#   'Limestone, Tennessee residents were promised economic benefits from a bitcoin mine, but now face constant noise pollution from its computers and cooling fans (Kevin Williams/Washington Post)',
#   'Crypto Price Prediction: Huge Bitcoin Forecast Revealed As Ethereum, BNB, XRP, Solana, Cardano, Luna And Avalanche Swing',
#   "Block's Revenue Is the Wrong Metric for Investors to Watch",
#   'Revisiting Bitcoin’s Energy ‘Problem’ in the Face of ESG Investment Mandates',
#   'Bitcoin Portfolio Insurance: Bond Risks And Contagion',
#   'First Mover Asia: Singapore-Based Gaming Company Razer Struggles to Pivot; Bitcoin Declines After a Positive Week',
#   'Crypto Cannot Be Cancelled – Implications For Investors',
#   '2022 Cryptocurrency & NFT Trading Bundle',
#   'Revisiting Bitcoin’s Energy ‘Problem’ in the Face of ESG Investment Mandates',
#   'SXSW 2022 showcased immersive NFT experiences, lacking crypto and Bitcoin sessions',
#   'Is Shiba Inu Winning as a Payment Method?',
#   '6 Questions for John deVadoss of Neo and the Global Blockchain Business Council',
#   'Every Bitcoin helps: Crypto-fueled relief aid for Ukraine',
#   'First Mover Asia: Singapore-Based Gaming Company Razer Struggles to Pivot; Bitcoin Declines After a Positive Week',
#   'Top 5 cryptocurrencies to watch this week: BTC, LUNA, AVAX, ETC, EGLD',
#   'Business briefs for 3-20-22 | Local News | wyomingnews.com - Wyoming Tribune',
#   'Sanjiv Bajaj at Idea Exchange: ‘The digital world is breaking old monopolies and driving competition because consumers have choices’'],
#  ["Is the US Developing a Digital Dollar? This Week's Top Bitcoin & Crypto News - CNET",
#   'Bitcoin to the rescue: Cryptocurrencies’ role in Ukraine',
#   'Bitcoin And Crypto Price Crash Triggers Serious Coinbase Warning',
#   'Can Shiba Inu Reach $1?',
#   'Bitcoin Lightning Network Continues To Grow',
#   'Bitcoin Is A Monetary System Of Integrity',
#   'Weekend Recovery Sees Ether Outperform Bitcoin as ETH Gains 5%',
#   "They thought they unearthed the world's largest potato. It turned out not to be a potato at all.",
#   'The Importance Of Attending Bitcoin Meetups In Person',
#   "Tom Brady makes Bitcoin offer for fan who spent over $500,000 on 'last' TD football - Fox Business",
#   'The Global Restaurant Brand With The Million Dollar NFT Membership Club',
#   '2 Metaverse Investments to Avoid Like the Plague',
#   'Why ApeCoin Is Climbing Again Today',
#   'The Stock Market: Fed Raises Policy Rate Of Interest, Stock Prices Rise',
#   'The ascent of crypto assets: Evolution and macro-financial drivers',
#   'With Six More Rate Hikes Planned for 2022, Here Are 3 Bank Stocks to Buy',
#   'Bitcoin beats owning COIN stock by 20% since Coinbase IPO',
#   'Buy The Crash: 2 Tech Stocks For 2022',
#   'BTC, ETH, AVAX and SOL Price Analysis for March 19 - U.Today',
#   'A detailed guide on how to lose all your Bitcoin investments'],
#  ['3 common tax mistakes first-time investors make',
#   "El Salvador's Companies Barely Bother With Bitcoin",
#   "Canada's Seizure Of Crypto From Freedom Convoy Highlights Digital Currency's Flaws",
#   'Why Crypto Mining Stocks Popped on Friday',
#   'This Senate Candidate Wants to Make Bitcoin Legal Tender With No Taxes',
#   'These were the 5 best performing cryptos over the past week amid the bitcoin bear market',
#   'The World Is Burning. Why Not Hoard Some Nickels?',
#   'Bitcoin Can Be The Foundation Of Human Rights',
#   'How To Set Up RoninDojo Tanto, A Powerful Privacy Tool For Bitcoin Transactions',
#   'Bitcoin Holding Above $40K, Resistance at $46K',
#   'Top cryptocurrency prices today: Avalanche jumps 5%; Solana, Polkadot and Bitcoin drop up to 3%',
#   'El Salvador’s Bitcoin Bond Issuance Apparently Delayed',
#   'Crypto is an Unproductive Bubble',
#   'Is Shiba Inu an Answer to Inflation? It Might Be in 1 Country',
#   'Save 98% off the Essential 2022 Cryptocurrency & NFT Trading Bundle',
#   'Market Wrap: Ether Outperforms, Bitcoin Rises Above $42K',
#   'SoftBank-Backed Broker Avenue Debuts Bitcoin Trading',
#   'Bitcoin Mining Pool Protocol Stratum V2 Is Making Progress',
#   'Bitcoin Mining Difficulty Drops for Second Time in March',
#   'Bitcoin Supply Dynamics Are Looking Extremely Strong'],
#  ['If you’re a Russian YouTuber, how do you get paid now?',
#   "Conti Leak: A Ransomware Gang's Chats Expose Its Crypto Plans",
#   'What are the environmental impacts of cryptocurrencies?',
#   'MetaMetaverse aims to make the metaverse interoperable',
#   'Blockchain Limitations to Consider Today',
#   'A look at the emergence of Kentucky as a small bitcoin mining powerhouse; an estimate says Kentucky produces more CO2 from crypto mining than any other US state (Avi Asher-Schapiro/Thomson Reuters ...)',
#   "DeFi's Dark Corners Evoke 2008 Crisis",
#   'Why Bitcoin, Ethereum, and Dogecoin Are Continuing to Rise Today',
#   'Inside a Bitcoin Mine at a Natural Gas Well In Texas',
#   'Bored Ape Yacht Club Owner Uses IP Ownership Rights to Open Restaurant',
#   'Senator Elizabeth Warren Introduces A Game-Changing Crypto Bill As The Price Of Bitcoin, Ethereum, BNB, XRP, Luna, Cardano, Solana And Avalanche Surge',
#   'ZEBEDEE Adds Lightning Off-Ramp For Bitcoin Gaming Rewards in Brazil',
#   'Bitcoin Miner TeraWulf Sets 2022 Hashrate Guidance',
#   'Bitcoin Holds Above $40K After Fed Hike, Avalanche’s AVAX Leads Gains Amongst Crypto Majors',
#   'Bit Digital: Future Looks Bright With Bitcoin Rebound',
#   'Learn how to build wealth with crypto and NFTs for just $30',
#   'Market Wrap: Bitcoin Stabilizes as Altcoins Take the Lead',
#   'Crypto Chartbook - Bitcoin Is Needed As An Alternative',
#   'The Fight Against Inflation Has Begun and Bitcoin is Ready to Help',
#   'First Mover Americas: Bitcoin Stays Above $40,000 While Ether Bounces on Testnet Success'],
#  ['Unearthing Found Footage From One of the First Bitcoin Conferences',
#   'Mike Novogratz says bitcoin won’t have a massive rally as Fed hikes rate and Russia-Ukraine war continues',
#   'Surviving Off Crypto When Cash Fails - CNET',
#   'ASIC mining: Computers built specifically for mining cryptocurrency',
#   "US stocks surge ahead of the Federal Reserve's expected first interest rate hike since 2018",
#   "Six months after El Salvador adopted Bitcoin as legal tender, citizens, economists, and tech developers reflect on the country's glitch-plagued initiative (Rest of World)",
#   'Boring Bitcoin And NFT Declines (Radio)',
#   '‘A torrent of abuse’: victims pin hopes on UK online safety bill',
#   'Why isn’t crypto an effective hedge?',
#   "Interview with Automattic CEO Matt Mullenweg on the company's growth, the future of open-source WordPress, Tumblr moderation, Web3, Bitcoin, Ethereum, and more (Nilay Patel/The Verge)",
#   'Why Bitcoin, Ethereum, and Dogecoin Are Gaining Today',
#   'Public Bitcoin Miners Are Increasing Hash Rates, BTC Holdings',
#   'The Best Global Crypto Exchanges',
#   'This Is the Catalyst That Will Drive Blockchain as Google, Facebook Hop On',
#   'Riot Blockchain Sees 2022 as Year of Consolidation in Bitcoin Mining Sector',
#   'Why Block Stock Was Up Over 8% Today',
#   'Market Wrap: Cryptos Recover From Drop After Fed Rate Hike; Expect Higher Volatility',
#   'Ukrainian President Zelensky Signs Law Legalizing Bitcoin',
#   'Bitcoin As Mutuality And Global Barter',
#   'Bitcoin Tops $41K in Crawl Back From $37K Weekend Lows'],
#  ["Cryptoverse: Bitcoin's scared of commitment, Mr Biden - Reuters.com",
#   "El Salvador is about to issue its billion-dollar bitcoin bond though the timing is tricky — 'I didn't expect the war in Ukraine'",
#   'Cryptocurrency payments are accepted the most by the travel industry, adoption study shows',
#   'ConsenSys valuation more than doubles to over $7 bln after latest funding - Reuters.com',
#   "The 'Freedom Convoy' Bitcoin Donations Have Been Frozen and Seized",
#   'US stocks rise as key Fed policy meeting kicks off and oil slips on new lockdowns in China',
#   'All eyes on approaching Fed meet, yen slips further - Reuters.com',
#   "Billionaire Mark Cuban takes a swipe at Elon Musk's question about what inflation could look like in the coming years",
#   "Six Months In, El Salvador's Bitcoin Gamble Is Crumbling",
#   'ExpressVPN vs. Surfshark: Which is the better VPN in 2022?',
#   "EU's Bitcoin Power Punt Is a Regulatory Dilemma",
#   'Crypto Mania in Texas Risks New Costs and Strains on Shaky Grid',
#   'Apple Cofounder Reveals Huge Bitcoin Price Prediction—And A Stark Crypto Warning As Ethereum, BNB, XRP, Luna, Cardano, Solana And Avalanche Ricochet',
#   'Which Country Mines the Most Bitcoin After China’s Ban?',
#   'How to Buy Cryptocurrency',
#   'Bitcoin Is Venice: What If You Knew The Renaissance Was Coming?',
#   'What Square’s Partnership With Codebase Means For British Start-Ups',
#   'Democrats divided over crypto’s future',
#   'Bitcoin: Another Detour On The Moonpath',
#   'Bitcoin Worth $1.2B Leaves Coinbase in a Sign of Persistent Institutional Adoption'],
#  ["Elon Musk Offers Advice on Inflation, Says He Won't Be Selling Crypto: 'It Is Generally Better to Own Physical Things'",
#   "Elon Musk advises owning 'physical things' like homes and stocks when inflation is high – but says he won't sell his bitcoin, ether, and dogecoin",
#   "Elon Musk advises owning 'physical things' like homes and stocks when inflation is high – but says he won't sell his bitcoin, ether, and dogecoin",
#   'Cryptocurrencies in 2022: An Interview with Tim Seymour and Meltem Demirors',
#   'Unearthing the Bitcoin Tapes',
#   'Investors turn to crypto funds, companies as Russia-Ukraine crisis escalates - Reuters.com',
#   'US stocks rise as Russia and Ukraine enter a new round of cease-fire talks',
#   'S&P 500 turns lower as Russia-Ukraine ceasefire talks pause ahead of Fed meeting',
#   'Yen slides to five-year lows at start of busy week for central banks - Reuters.com',
#   'Why crypto is unlikely to be useful for sanctions-dodgers',
#   'The Benefits Of Venture Capital In Web3',
#   'The Bull Case for Bitcoin',
#   'Robo Money: Best Robo Advisor Apps to Help You Automate Investments',
#   'EU Parliament committee rejects a provision for its Markets in Crypto Assets framework that would have limited the use of proof-of-work cryptocurrencies (Sandali Handagama/CoinDesk)',
#   "Crypto miners, who scrambled into a welcoming Kazakhstan after China's ban, are leaving as the country throttles power supply due to blackouts and infighting (Rest of World)",
#   "How inheritance issues strike at the root of crypto's libertarian ethos, as disdain for institutions and lack of legal guidance leads to problems for inheritors (Rebecca Heilweil/Vox)",
#   'Crypto: EU proposal seen as de facto Bitcoin ban fails in vote',
#   'How Wall Street star Cathie Wood is defying her doubters - Reuters.com',
#   'Blockchain in Clinical Trials: Can it Improve Transparency?',
#   'Canaan Plunges 15% as Regulation Set to Hit Crypto Mining Sector'],
#  ["Sam Bankman-Fried says Biden's crypto order won't move the needle, but Cameron WInklevoss calls it a watershed. Here are the 8 top reaction quotes from crypto players.",
#   'A Guide for Accepting Bitcoin at Your Ecommerce Store',
#   'Learn More About Crypto, NFTs, and the Metaverse',
#   'The Luxury Watch Market Presents Opportunities for the Savvy Investor',
#   'Why crypto is unlikely to be useful for sanctions-dodgers',
#   'Sanctions-dodgers hoping to use crypto to evade detection are likely to be disappointed',
#   "Bitcoin was made for this moment. So why isn't it Booming?",
#   'What Does The Future Hold For Bitcoin Mining?',
#   'Bitcoin Warning: Should You Listen To The FCA’s Extreme Bearishness?',
#   'Bitcoin: Gold 2.0? Try Reserve Asset 3.0',
#   'Bitcoin – The Open Money And Its Enemies',
#   "First Mover Asia: South Korea Election Made Crypto a Big Issue, but There's No Guarantee of a Follow-Through; Cryptos Suffer Weekend Decline",
#   'Proof Of Reserves – The Making Of A Bitcoin Industry Standard',
#   'Bitcoin: Gold 2.0? Try Reserve Asset 3.0',
#   "Bitcoin-Banning Measure Seen Too Close to Call in Tomorrow's EU Parliament Vote",
#   "Bitcoin-Banning Measure Seen Too Close to Call in Tomorrow's EU Parliament Vote",
#   'GMiners Announces the Launch of the Game-Changing Cloud Mining Platform',
#   'Crypto Tax Software: Manage Bitcoin and Other Digital Currencies - CNET',
#   'Bitcoin drifts into weekly close while Fed rate hike looms as next major BTC price trigger',
#   'Tug-of-War Between Newbies, Crypto 1% Keeps Bitcoin Range-Bound'],
#  ["Why Isn't Bitcoin Booming?",
#   'Social Media Effects on Bitcoin',
#   'eBay Hints at Digital Wallet for Q2',
#   '2 Top Cryptocurrencies To Buy and Hold Forever',
#   'Want to Get Richer? 1 Top Cryptocurrency to Buy Right Now Without Hesitation',
#   'Bitcoin boom or crypto winter? Key levels to watch on upside & downside',
#   'US Treasury Launching Cryptocurrency Awareness Program – Regulation Bitcoin News - Bitcoin News',
#   'The Price Of Ripple’s XRP Is Suddenly Surging As Bitcoin, Ethereum, BNB, Solana, Cardano, Terra’s Luna And Avalanche Are Flatflining',
#   'A Legendary Investor Just Predicted The End Of The U.S. Dollar—And Warned Over The Future Of Bitcoin Amid Extreme Crypto Price Swings',
#   'Crypto Wallet fob concept gives digital currency a physical form',
#   'Fedimint – The Evolution Of Bitcoin Custody',
#   'Reputational Annihilation: Keeping Your Word In Bitcoin',
#   'How Bitcoin Mining Strengthens Electricity Grids',
#   'Bitcoin, Tectonic Shifts In The Financial System And Oil',
#   'As U.S. Inflation Hits 7.91%,\xa0 Negative Impact On Bitcoin Price Looming',
#   "‘My pension costs me too much in tax – I'm buying Bitcoin instead'",
#   'Free From Politics, Bitcoin Is A Platform For Independent Philanthropy',
#   'Russians liquidating crypto in UAE in hunt for safe havens',
#   'What Is Shiba Inu & Is It Like Dogecoin?',
#   'Can Shiba Inu Reach $0.0001 in 2022?'],
#  ['El Salvador says could launch bitcoin sovereign bond between March 15-20 - Reuters',
#   'These were the 5 worst performing cryptos over the past week amid the bitcoin bear market',
#   "The US dollar could go digital. Here's what you need to know",
#   'UK Regulators Order Shutdown of Cryptocurrency ATMs - CNET',
#   'EXCLUSIVE Russians liquidating crypto in the UAE to seek safe havens - Reuters.com',
#   "US stocks gain after Putin says talks between Russia and Ukraine have made 'progress'",
#   'Dollar hits 5-year high on yen, euro pressured by growth risks - Reuters',
#   'US stocks fall as volatility from the Ukraine-Russia crisis keeps investors on edge',
#   'Lil Durk Drops New LP ‘7220’ With Appearances From Future, Gunna and More',
#   'Bitcoin cash machines ordered to shut down in UK',
#   '3 Top Cryptos That Are Now Down Big Over the Past Year',
#   'Bitcoin’s Value Drops\xa0Amid Russia-Urkaine War and Inflation',
#   "Intel's new Bitcoin mining chip is already gaining serious traction",
#   "Daymond John Says Biden's Crypto Executive Order is Good News for Investors",
#   'Cryptocurrency Fuels Explosive Growth of Crime',
#   'A La Carte (March 11)',
#   'How To Recover Bitcoin Wallet',
#   'SEC Rejects NYDIG, Global X Spot Bitcoin ETF Applications',
#   'UK tells operators to shut down crypto ATMs or face action',
#   'Market Wrap: Cryptos Mixed Amid Global Uncertainty'],
#  ['Verdict against self-proclaimed Bitcoin inventor balloons to $143 mln - Reuters.com',
#   'Bitcoin Skyrockets After Biden Sign Executive Order to Regulate Crypto',
#   'Ex-Canadian government official extradited to face charges over ransomware attacks - Reuters.com',
#   'US Extradites Canadian for Ransomware After Officials Seize $28M in Cryptocurrency - CNET',
#   'NetWalker: Sebastien Vachon-Desjardins extradited to US - CTV News',
#   "We Filmed at a Bitcoin Conference in 2013. Here's What Those People Are Doing Now",
#   'Chevron Corp, Goldman Sachs, Inari Medical - Reuters.com',
#   "Asana, Build-A-Bear, Pilgrim's Pride - Reuters.com",
#   'US stocks fall as inflation soars in February and Russia-Ukraine talks stall',
#   'US stocks fall in volatile trading as inflation surges again and Ukraine-Russia crisis drags on',
#   'Free Bitcoin, Microsoft Drops Russia, Switch to a Cellular iPad, and Answer Security Questions Wrong',
#   'US stock futures dip as investors focus on diplomatic talks between Russia and Ukraine ahead of key inflation data',
#   'The SEC’s Former Head of Internet Enforcement Fears How the Crypto Story Ends',
#   'What is blockchain technology and how does it work?',
#   'Why Bitcoin, Ethereum, and Dogecoin Dropped Today',
#   'The Crypto World Is Still Waiting for Its Rulebook',
#   'Biden Orders Report on Climate Risk of Cryptocurrencies',
#   'War in Ukraine could drive more people to crypto, analysts say',
#   'Outdoor Voices’ Ty Haney Starts New Company in Web3 Space',
#   'Nonfungible.com: NFT game sales hit $5.17B in 2021']]

# %%
# Instantiate SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

# %%
# Create function that computes average compound sentiment of headlines for each day
def headline_sentiment_summarizer_avg(headlines):
    sentiment = []
    for day in headlines:
        day_score = []
        for h in day:
            if h == None:
                continue
            else:
                day_score.append(sid.polarity_scores(h)["compound"])
        sentiment.append(sum(day_score) / len(day_score))
    return sentiment

# %%
# Get averages of each topics sentiment
eth_avg = headline_sentiment_summarizer_avg(eth_headlines)
btc_avg = headline_sentiment_summarizer_avg(btc_headlines)

# %%
# Combine Sentiment Averages into DataFrame
topic_sentiments = pd.DataFrame(
    {
        "eth_avg": eth_avg,
        "btc_avg": btc_avg,
    }
)

# %%
# Set the index value of the sentiment averages DataFrame to be the series of dates.
topic_sentiments.index = pd.to_datetime(dates)

# %%
# Merge with BTC & ETH returns
topic_sentiments = eth_returns.join(topic_sentiments).dropna(how="any")

# Display data
display(topic_sentiments)
# Out:
# Empty DataFrame
# Columns: [close, eth_avg, btc_avg]
# Index: []

# %%
# Correlate the headlines' sentiment to returns
topic_sentiments.corr().style.background_gradient()
# Out:
# C:\Users\CharbelNehme\anaconda3\envs\dev\lib\site-packages\pandas\io\formats\style.py:3554: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# C:\Users\CharbelNehme\anaconda3\envs\dev\lib\site-packages\pandas\io\formats\style.py:3555: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_582ce_row0_col0, #T_582ce_row0_col1, #T_582ce_row0_col2, #T_582ce_row1_col0, #T_582ce_row1_col1, #T_582ce_row1_col2, #T_582ce_row2_col0, #T_582ce_row2_col1, #T_582ce_row2_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_582ce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_582ce_level0_col0" class="col_heading level0 col0" >close</th>
#       <th id="T_582ce_level0_col1" class="col_heading level0 col1" >eth_avg</th>
#       <th id="T_582ce_level0_col2" class="col_heading level0 col2" >btc_avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_582ce_level0_row0" class="row_heading level0 row0" >close</th>
#       <td id="T_582ce_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_582ce_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_582ce_row0_col2" class="data row0 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_582ce_level0_row1" class="row_heading level0 row1" >eth_avg</th>
#       <td id="T_582ce_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_582ce_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_582ce_row1_col2" class="data row1 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_582ce_level0_row2" class="row_heading level0 row2" >btc_avg</th>
#       <td id="T_582ce_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_582ce_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_582ce_row2_col2" class="data row2 col2" >nan</td>
#     </tr>
#   </tbody>
# </table>
